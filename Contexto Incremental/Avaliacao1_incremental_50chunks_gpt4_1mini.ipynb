# %%
#Consulta em Duas Etapas (Retrieve & Re-rank):
#Etapa 1 (Recuperação Inicial): Buscar os 100 chunks mais próximos da pergunta usando a similaridade de cossenos (recuperação "bruta").
#Etapa 2 (Reordenamento com Gemini): Enviar esses 100 chunks para o Gemini com um prompt específico, pedindo para ele reordená-los com base na relevância textual para a pergunta.
#Etapa 3 (Avaliação recuperação): Avalia pelo número do id o ranqueamento dos chunks com as métricas MRR / Precision@k / NDCG@k 

import psycopg2
import numpy as np
import pandas as pd
import requests
from scipy.spatial.distance import cosine # Importando a distância de cosseno
from sentence_transformers import SentenceTransformer
import json
import tkinter as tk
from tkinter import messagebox
import time
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from sklearn.decomposition import PCA
import matplotlib.patches as patches
import traceback
import re
from sentence_transformers import CrossEncoder
from rank_bm25 import BM25Okapi
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from openai import OpenAI
# Listas globais para armazenar os rankings de todas as chamadas
lista_ids_ordem_cosseno = []
lista_ids_reordenados_int = []

# --- CONFIGURAÇÕES ---
# Inicializar modelo para gerar o embedding da consulta
print("Carregando o modelo de embeddings...")
modelo = SentenceTransformer('intfloat/multilingual-e5-small')
print("Modelo carregado.")



client = OpenAI(api_key="Chave API")
MODEL_NAME = "gpt-4.1-mini"

# Configurações do Banco de Dados
DB_HOST = "localhost"
DB_NAME = "postgres" # Nome do banco de dados
DB_USER = "postgres"
DB_PORT = 5432
DB_PASS = "senha" 
DB_TABLE = "texto_avaliacao_ebserh" # Nome da tabela com os dados

# --- FUNÇÕES DE BANCO DE DADOS E LÓGICA DE RAG ---

def buscar_todos_os_dados():
    """Busca todos os dados necessários (id, texto_artigo, vector, texto_pagina) do banco."""
    try:
        conexao = psycopg2.connect(host=DB_HOST, port=DB_PORT, database=DB_NAME, user=DB_USER, password=DB_PASS)
        cursor = conexao.cursor()
        
        # Seleciona todas as colunas que serão usadas no processo
        cursor.execute(f"SELECT id, texto_artigo, vector, texto_pagina, nome_arquivo FROM {DB_TABLE}")
        
        resultados = cursor.fetchall()
        cursor.close()
        conexao.close()
        print(f"Encontrados {len(resultados)} registros no banco de dados.")
        return resultados
    except Exception as e:
        print(f"Erro ao conectar ou buscar dados do banco: {e}")
        return []

def recuperacao_inicial_por_similaridade(query_embedding, dados_banco, k=100):
    """
    Calcula a similaridade de cossenos e retorna os k chunks mais próximos.
    A distância de cosseno é 1 - similaridade de cosseno. Menor distância = maior similaridade.
    """
    # Calcula a distância de cosseno entre a query e todos os embeddings do banco
    # A estrutura de 'dado' agora é (id, texto_artigo, vector, texto_pagina)
    resultados_com_distancia = [
        (dado, cosine(query_embedding, np.array(json.loads(dado[2])).flatten()))
        for dado in dados_banco
    ]
    
    # Ordena pela distância (menor para o maior) e pega os top k
    resultados_ordenados = sorted(resultados_com_distancia, key=lambda x: x[1])[:k]
    
    # Retorna apenas os dados dos chunks, sem a distância
    top_k_chunks = [dado for dado, dist in resultados_ordenados]
    print(f"Recuperação inicial concluída. {len(top_k_chunks)} chunks selecionados.")
    return top_k_chunks
    #print(f"Recuperação inicial concluída. {len(resultados_ordenados)} chunks selecionados a partir de registros válidos.")
    #return resultados_ordenados # Retorna a lista de tuplas (dado, distancia)

def imprimir_rankings_para_comparacao(top_100_chunks, top_100_rrf):
    global lista_ids_ordem_cosseno, lista_ids_reordenados_int

    # 1. Extrai a lista de IDs da busca por cosseno (são inteiros)
    ids_ordem_cosseno = [chunk[0] for chunk in top_100_chunks]
    ids_ordem_rrf = [chunk[0] for chunk in top_100_rrf]
    # 2. Converte os IDs do Gemini (que são strings) para inteiros para uma comparação justa
   # ids_reordenados_int = []
   # for id_str in ids_reordenados:
       # try:
          #  ids_reordenados_int.append(int(id_str))
        #except (ValueError, TypeError):
           # print(f"Aviso: ID '{id_str}' retornado pelo Gemini não é um inteiro e será ignorado.")

    # 3. Armazena os rankings gerados nesta chamada
    lista_ids_ordem_cosseno.append(ids_ordem_cosseno)
    lista_ids_reordenados_int.append(ids_ordem_rrf)

def bm25_rank(top_chunks, query):
    """
    Recebe os 100 chunks recuperados por similaridade de cosseno e realiza reranqueamento com BM25.
    Retorna os mesmos chunks ordenados pela relevância BM25.
    """
    # Extrair os textos dos chunks (ajuste o índice conforme necessário)
    textos = [chunk[1] for chunk in top_chunks]  # Exemplo: chunk[1] é o 'texto_artigo'

    # Tokenização
    corpus_tokenizado = [word_tokenize(doc.lower()) for doc in textos]
    query_tokenizada = word_tokenize(query.lower())

    # Inicializa o modelo BM25
    bm25 = BM25Okapi(corpus_tokenizado)

    # Calcula os scores
    scores = bm25.get_scores(query_tokenizada)

    # Associa cada chunk ao seu score
    chunks_com_score = list(zip(top_chunks, scores))

    # Ordena pelo score decrescente
    rerankeado = sorted(chunks_com_score, key=lambda x: x[1], reverse=True)

    # Retorna só os chunks reranqueados
    return [chunk for chunk, score in rerankeado]

# ======= RRF =======

def rrf_rank(ranking1, ranking2, k=60):
    """
    Aplica Reciprocal Rank Fusion (RRF) nos rankings de chunks.
    Recebe dois rankings (listas de chunks) e retorna uma lista de chunks reranqueada.
    """
    from collections import defaultdict

    # Mapeia IDs para os próprios chunks
    id_para_chunk = {chunk[0]: chunk for chunk in ranking1 + ranking2}

    # Inicializa os scores RRF
    scores_rrf = defaultdict(float)

    # Ranking 1: Similaridade de Cosseno
    for rank, chunk in enumerate(ranking1):
        chunk_id = chunk[0]
        scores_rrf[chunk_id] += 1 / (k + rank)

    # Ranking 2: BM25
    for rank, chunk in enumerate(ranking2):
        chunk_id = chunk[0]
        scores_rrf[chunk_id] += 1 / (k + rank)

    # Ordena os chunks por score RRF
    ids_ordenados = sorted(scores_rrf.items(), key=lambda x: x[1], reverse=True)

    # Retorna a lista de chunks reranqueada
    return [id_para_chunk[chunk_id] for chunk_id, _ in ids_ordenados]


def rag_incremental(query, top_chunks, step=5, max_k=50):
    print("\n🚀 Iniciando RAG Incremental...")

    k = step
    total_tokens = 0
    num_chamadas = 0

    while k <= max_k:
        print(f"\n🔎 Testando com top-{k} chunks")

        subset = top_chunks[:k]

        contexto = [
            {"texto": chunk[3], "fonte": chunk[4]}
            for chunk in subset
        ]

        # Monta prompt (para contar tokens)
        contexto_str = " ".join([c["texto"] for c in contexto])
        prompt_estimado = f"{query} {contexto_str}"

        tokens_prompt = estimar_tokens(prompt_estimado)

        # chamada principal
        resposta = gerar_resposta_incremental_gpt(query, contexto)
        num_chamadas += 1

        tokens_resposta = estimar_tokens(resposta)
        total_tokens += tokens_prompt + tokens_resposta

        print("Resposta:", resposta)

        if "NÃO ENCONTRADO" in resposta:
            k += step
            continue

        # 🔍 verificação
        prompt_verificacao = f"{query} {resposta} {contexto_str}"
        tokens_verificacao_prompt = estimar_tokens(prompt_verificacao)

        valido = verificar_resposta_gpt(query, resposta, contexto)
        num_chamadas += 1

        tokens_verificacao_resposta = estimar_tokens(str(valido))
        total_tokens += tokens_verificacao_prompt + tokens_verificacao_resposta

        print("✔ Validação:", valido)

        if valido:
            print(f"✅ Resposta encontrada com top-{k}")
            return {
                "resposta": resposta,
                "k_utilizado": k,
                "status": "SUCESSO",
                "num_chamadas": num_chamadas,
                "tokens_estimados": total_tokens
            }
        else:
            print("❌ Falso positivo, continuando...")
            k += step

    return {
        "resposta": "NÃO ENCONTRADO",
        "k_utilizado": max_k,
        "status": "FALHA",
        "num_chamadas": num_chamadas,
        "tokens_estimados": total_tokens
    }

def orquestrar_rag_duas_etapas(query):
    dados_banco = buscar_todos_os_dados()
    if not dados_banco:
        return {
            "resposta": "Erro ao recuperar dados",
            "k_utilizado": 0,
            "num_chamadas": 0,
            "tokens_estimados": 0,
            "status": "ERRO"
        }

    # 🔹 Embedding da query
    embedding_query = modelo.encode(query).tolist()

    # 🔹 Recuperação inicial
    top_100_chunks = recuperacao_inicial_por_similaridade(
        embedding_query, dados_banco, k=100
    )

    # 🔹 BM25
    top_100_bm25 = bm25_rank(top_100_chunks, query)

    # 🔹 RRF
    top_100_rrf_chunks = rrf_rank(top_100_chunks, top_100_bm25, k=60)

    time.sleep(4)

    if not top_100_rrf_chunks:
        return {
            "resposta": "Erro no reranqueamento",
            "k_utilizado": 0,
            "num_chamadas": 0,
            "tokens_estimados": 0,
            "status": "ERRO"
        }

    print(f"🔎 Total de chunks disponíveis: {len(top_100_rrf_chunks)}")

    # 🔹 Estimativa custo Top-50 (baseline)
    tokens_top50 = estimar_tokens_topk(query, top_100_rrf_chunks, k=50)

    # 🚀 🔥 NOVA PARTE: RAG INCREMENTAL
    resultado_incremental = rag_incremental(
        query,
        top_100_rrf_chunks,
        step=5,     # tamanho do bloco
        max_k=50    # limite máximo
    )

    resultado_incremental["tokens_top50"] = tokens_top50

    # economia percentual
    if tokens_top50 > 0:
        resultado_incremental["economia_tokens"] = 1 - (
            resultado_incremental["tokens_estimados"] / tokens_top50
        )
    else:
        resultado_incremental["economia_tokens"] = 0

    return resultado_incremental
# --- BLOCO DE 
  
def gerar_resposta_incremental_gpt(query, chunks):
    contexto = ""
    for i, chunk in enumerate(chunks):
        contexto += f"Documento {i+1}:\n{chunk['texto']}\n\n"

    prompt = f"""
Você é um especialista em análise de documentos.

Sua tarefa é responder à pergunta com base nos textos fornecidos.

⚠️ REGRAS IMPORTANTES:
- Gere UMA ÚNICA resposta final
- NÃO responda por documento
- NÃO escreva "Documento 1", "Documento 2", etc.
- NÃO liste múltiplas respostas separadas
- NÃO repita trechos
- Seja objetiva e direta

- Se a resposta NÃO estiver presente nos textos, responda exatamente:
NÃO ENCONTRADO

Pergunta:
{query}

Documentos:
{contexto}
"""

    try:
        response = client.responses.create(
            model=MODEL_NAME,
            input=prompt,
            temperature=0
        )

        resposta = response.output_text.strip()
        return resposta

    except Exception as e:
        print("Erro GPT incremental:", e)
        return "ERRO"
        
def verificar_resposta_gpt(query, resposta, chunks):
    contexto = ""
    for i, chunk in enumerate(chunks):
        contexto += f"Documento {i+1}:\n{chunk['texto']}\n\n"

    prompt = f"""
A resposta abaixo está REALMENTE suportada pelos documentos?

Responda apenas com:
SIM ou NÃO

Pergunta:
{query}

Resposta:
{resposta}

Documentos:
{contexto}
"""

    try:
        response = client.responses.create(
            model=MODEL_NAME,
            input=prompt,
            temperature=0
        )

        validacao = response.output_text.strip().upper()
        return "SIM" in validacao

    except Exception as e:
        print("Erro verificação GPT:", e)
        return False

def estimar_tokens(texto):
    if not texto:
        return 0
    return int(len(texto) / 4)

def estimar_tokens_topk(query, top_chunks, k=50):
    subset = top_chunks[:k]

    contexto = " ".join([chunk[3] for chunk in subset])

    prompt = f"""
    Responda à pergunta com base nos documentos abaixo.

    Pergunta:
    {query}

    Documentos:
    {contexto}
    """

    tokens_prompt = estimar_tokens(prompt)

    # Estimativa de resposta média (ajuste se quiser)
    tokens_resposta = 200  

    return tokens_prompt + tokens_resposta

def buscar_perguntas(limit=193):
    try:
        # --------------------------------------------------
        # 1) Leitura do CSV
        # --------------------------------------------------
        df = pd.read_csv(
            "perguntas_respostas_unificadas.xls",
            encoding="utf-8"
        )

        # --------------------------------------------------
        # 2) Seleciona as primeiras perguntas (ordem do CSV)
        # --------------------------------------------------
        perguntas = df["pergunta"].head(limit).tolist()

        return perguntas

    except Exception as e:
        print("❌ Erro ao buscar perguntas do arquivo CSV:")
        traceback.print_exc()
        return []

     
# --- BLOCO DE EXECUÇÃO PRINCIPAL ---
if __name__ == "__main__":
    perguntas = buscar_perguntas(limit=193)
    list_respostas = []
    
    for i, pergunta in enumerate(perguntas, 1):
        print(f"\n🔍 Processando pergunta {i}: \"{pergunta}\"\n")

        try:
            resultado = orquestrar_rag_duas_etapas(pergunta)


            list_respostas.append({
                "pergunta": pergunta,
                "resposta": resultado.get("resposta", ""),
                "k_utilizado": resultado.get("k_utilizado", 0),
                "num_chamadas": resultado.get("num_chamadas", 0),
                "tokens_incremental": resultado.get("tokens_estimados", 0),
                "tokens_top50": resultado.get("tokens_top50", 0),
                "economia_tokens": resultado.get("economia_tokens", 0),
                "status": resultado.get("status", "")
            })
           

            print("\n" + "="*100 + f" RESPOSTA {i} " + "="*100)
            print("Resposta:", resultado.get("resposta", ""))
            print("k_utilizado:", resultado.get("k_utilizado", 0))
            print("num_chamadas:", resultado.get("num_chamadas", 0))
            print("tokens_estimados:", resultado.get("tokens_estimados", 0))
            print("status:", resultado.get("status", ""))
            print("="*192)

            print(f"""
            📊 Comparação de custo:
            - Tokens incremental: {resultado.get("tokens_estimados", 0)}
            - Tokens Top-50: {resultado.get("tokens_top50", 0)}
            - Economia: {resultado.get("economia_tokens", 0)*100:.2f}%
            """)
                     
            
        except Exception as e:
            print(f"\n--- ERRO ao processar pergunta {i} ---")
            traceback.print_exc()
    # Criação dos DataFrames
    df_respostas = pd.DataFrame(list_respostas)
   
    # Salva resultados em arquivos CSV
    df_respostas.to_csv('resultados_incremental_gpt4_1mini.csv')
    
   # print("\n📋 DataFrame - Cosine")
   # print(df_cosine.head())

    print("\n📋 DataFrame - Respostas")
    print(df_respostas.head())
    print("\n✅ Todas as perguntas foram processadas.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mvcun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Carregando o modelo de embeddings...
# Modelo carregado.
#
# 🔍 Processando pergunta 1: "Quais formulários são mencionados no documento como disponíveis no site do HE -> Sistemas -> ADS Hospitalar -> Documentos -> USOST – Unidade de Saúde Ocupacional e Segurança do Trabalho, e para quais finalidades são utilizados?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os formulários mencionados no documento como disponíveis no site do HE -> Sistemas -> ADS Hospitalar -> Documentos -> USOST – Unidade de Saúde Ocupacional e Segurança do Trabalho, e suas finalidades são:
#
# 1. **Formulário USOST-027 – Permissão de Trabalho de Risco (PTR)**
#    - Utilizado para atividades não rotineiras com validade de 1 dia ou atividades previamente programadas com validade de até 5 dias.
#    - Destina-se a autorizar e controlar trabalhos com risco, incluindo descrição da atividade, perigos envolvidos, EPIs necessários e declaração de ciência dos executantes.
#
# 2. **Formulário USOST-029 – Autorização para trabalho a quente**
#    - Deve ser emitido juntamente com a PTR para atividades que envolvam fontes de ignição, como aquecimento, centelha ou chama, em áreas com presença de material inflamável ou combustível.
#
# 3. **Formulário USOST-030 – Permissão de Entrada e Trabalho em espaços confinados (PET)**
#    - Emitido juntamente com a PTR para trabalhos em espaços confinados, contendo informações sobre riscos, medidas de controle, e deve ser mantido pelo supervisor de entrada e vigia.
#
# 4. **Formulário USOST-039 – Etiqueta bloqueio de energias perigosas**
#    - Emitido juntamente com a PTR para bloqueio e etiquetagem de energias perigosas (elétrica, mecânica, hidráulica, pneumática, química, térmica), para impedir acionamento acidental de fontes de energia durante manutenção ou limpeza.
#
# Esses formulários são utilizados para garantir a segurança e o controle das atividades de risco, trabalho a quente, entrada em espaços confinados e bloqueio de energias perigosas.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 1 ====================================================================================================
# Resposta: Os formulários mencionados no documento como disponíveis no site do HE -> Sistemas -> ADS Hospitalar -> Documentos -> USOST – Unidade de Saúde Ocupacional e Segurança do Trabalho, e suas finalidades são:
#
# 1. **Formulário USOST-027 – Permissão de Trabalho de Risco (PTR)**
#    - Utilizado para atividades não rotineiras com validade de 1 dia ou atividades previamente programadas com validade de até 5 dias.
#    - Destina-se a autorizar e controlar trabalhos com risco, incluindo descrição da atividade, perigos envolvidos, EPIs necessários e declaração de ciência dos executantes.
#
# 2. **Formulário USOST-029 – Autorização para trabalho a quente**
#    - Deve ser emitido juntamente com a PTR para atividades que envolvam fontes de ignição, como aquecimento, centelha ou chama, em áreas com presença de material inflamável ou combustível.
#
# 3. **Formulário USOST-030 – Permissão de Entrada e Trabalho em espaços confinados (PET)**
#    - Emitido juntamente com a PTR para trabalhos em espaços confinados, contendo informações sobre riscos, medidas de controle, e deve ser mantido pelo supervisor de entrada e vigia.
#
# 4. **Formulário USOST-039 – Etiqueta bloqueio de energias perigosas**
#    - Emitido juntamente com a PTR para bloqueio e etiquetagem de energias perigosas (elétrica, mecânica, hidráulica, pneumática, química, térmica), para impedir acionamento acidental de fontes de energia durante manutenção ou limpeza.
#
# Esses formulários são utilizados para garantir a segurança e o controle das atividades de risco, trabalho a quente, entrada em espaços confinados e bloqueio de energias perigosas.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 7517
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 7517
#             - Tokens Top-50: 101735
#             - Economia: 92.61%
#
#
# 🔍 Processando pergunta 2: "De acordo com o documento, qual é a definição de Estágio Optativo para acadêmicos de Medicina ou residentes?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: De acordo com o documento 1 (e também repetido no documento 2), a definição de Estágio Optativo para acadêmicos de Medicina ou residentes é:
#
# "Estágio Optativo é atividade curricular obrigatória, porém em área eletiva, ou seja, escolhida pelo próprio estudante."
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 2 ====================================================================================================
# Resposta: De acordo com o documento 1 (e também repetido no documento 2), a definição de Estágio Optativo para acadêmicos de Medicina ou residentes é:
#
# "Estágio Optativo é atividade curricular obrigatória, porém em área eletiva, ou seja, escolhida pelo próprio estudante."
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 10150
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 10150
#             - Tokens Top-50: 66961
#             - Economia: 84.84%
#
#
# 🔍 Processando pergunta 3: "Quais são os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL, de acordo com o documento?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL, de acordo com o documento, são:
#
# Para Acadêmicos da UFPEL:
# - Plano de Ensino, preenchido e assinado em conjunto com o supervisor do estágio;
# - Declaração de seguro fornecida pelo colegiado da Faculdade de Medicina (FAMED).
#
# Para Acadêmicos de outras Instituições:
# - Termo de Compromisso de Estágio (3 vias), assinado pelo acadêmico e pela instituição de ensino;
# - Plano de Ensino, preenchido e assinado em conjunto com o professor coordenador de estágios (caso a Instituição de Ensino não tenha modelo próprio, pode ser usado o modelo da GEP);
# - Carta de apresentação fornecida pela Instituição de Ensino, mencionando nome do estudante, situação atual de matrícula, nome da disciplina de estágio obrigatório que deve realizar e carga horária total que deve cumprir;
# - Cópia de apólice de seguro contra acidentes pessoais, ou declaração da Instituição de Ensino atestando que o estudante está assegurado (mencionar nome da seguradora, número da apólice e prazo de vigência);
# - Cópia de comprovante vacinal (carteirinha de vacinação) com as doses de Hepatite B e Dupla Adulto (Tétano, Difteria) em dia.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 3 ====================================================================================================
# Resposta: Os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL, de acordo com o documento, são:
#
# Para Acadêmicos da UFPEL:
# - Plano de Ensino, preenchido e assinado em conjunto com o supervisor do estágio;
# - Declaração de seguro fornecida pelo colegiado da Faculdade de Medicina (FAMED).
#
# Para Acadêmicos de outras Instituições:
# - Termo de Compromisso de Estágio (3 vias), assinado pelo acadêmico e pela instituição de ensino;
# - Plano de Ensino, preenchido e assinado em conjunto com o professor coordenador de estágios (caso a Instituição de Ensino não tenha modelo próprio, pode ser usado o modelo da GEP);
# - Carta de apresentação fornecida pela Instituição de Ensino, mencionando nome do estudante, situação atual de matrícula, nome da disciplina de estágio obrigatório que deve realizar e carga horária total que deve cumprir;
# - Cópia de apólice de seguro contra acidentes pessoais, ou declaração da Instituição de Ensino atestando que o estudante está assegurado (mencionar nome da seguradora, número da apólice e prazo de vigência);
# - Cópia de comprovante vacinal (carteirinha de vacinação) com as doses de Hepatite B e Dupla Adulto (Tétano, Difteria) em dia.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 10164
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 10164
#             - Tokens Top-50: 80746
#             - Economia: 87.41%
#
#
# 🔍 Processando pergunta 4: "Quais são os materiais necessários para o preenchimento do Sistema ADS Ensino para o cadastro de estágios curriculares obrigatórios, incluindo a impressão dos crachás de identificação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os materiais necessários para o preenchimento do Sistema ADS Ensino para o cadastro de estágios curriculares obrigatórios, incluindo a impressão dos crachás de identificação, são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
#
# (Documento 2, MATERIAL)
#
# Além disso, para a impressão dos crachás, deve-se salvar o arquivo PDF em pen drive para impressão em equipamento de impressão colorida do Hospital Escola, plastificar o crachá e entregá-lo na portaria ou no Setor de Ensino para retirada pelo estagiário. (Documento 2, Ação 5)
#
# Portanto, os materiais necessários são:
#
# - Computador com Internet
# - Sistema ADS Ensino
# - Pen drive (para salvar o arquivo PDF do crachá)
# - Impressora colorida (do Hospital Escola)
# - Papel A4 (implícito para impressão)
# - Plástico para plastificação do crachá (implícito na etapa de plastificação)
#
# Obs.: O Documento 2 não menciona explicitamente papel A4 e plástico, mas o Documento 1, que trata de estágio optativo, menciona esses materiais para impressão e plastificação do crachá. Como a pergunta é sobre estágio curricular obrigatório, e o Documento 2 não menciona papel A4 e plástico, a resposta deve se limitar ao que está no Documento 2.
#
# Resposta final:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Pen drive (para salvar o arquivo PDF do crachá)
# - Impressora colorida do Hospital Escola
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 4 ====================================================================================================
# Resposta: Os materiais necessários para o preenchimento do Sistema ADS Ensino para o cadastro de estágios curriculares obrigatórios, incluindo a impressão dos crachás de identificação, são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
#
# (Documento 2, MATERIAL)
#
# Além disso, para a impressão dos crachás, deve-se salvar o arquivo PDF em pen drive para impressão em equipamento de impressão colorida do Hospital Escola, plastificar o crachá e entregá-lo na portaria ou no Setor de Ensino para retirada pelo estagiário. (Documento 2, Ação 5)
#
# Portanto, os materiais necessários são:
#
# - Computador com Internet
# - Sistema ADS Ensino
# - Pen drive (para salvar o arquivo PDF do crachá)
# - Impressora colorida (do Hospital Escola)
# - Papel A4 (implícito para impressão)
# - Plástico para plastificação do crachá (implícito na etapa de plastificação)
#
# Obs.: O Documento 2 não menciona explicitamente papel A4 e plástico, mas o Documento 1, que trata de estágio optativo, menciona esses materiais para impressão e plastificação do crachá. Como a pergunta é sobre estágio curricular obrigatório, e o Documento 2 não menciona papel A4 e plástico, a resposta deve se limitar ao que está no Documento 2.
#
# Resposta final:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Pen drive (para salvar o arquivo PDF do crachá)
# - Impressora colorida do Hospital Escola
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 13345
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 13345
#             - Tokens Top-50: 60405
#             - Economia: 77.91%
#
#
# 🔍 Processando pergunta 5: "Quais são os materiais necessários para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os materiais necessários para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Impressora Ink Jet ou Laser colorida
# - Papel A4
# - Plástico Polaseal para plastificação do crachá
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 5 ====================================================================================================
# Resposta: Os materiais necessários para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Impressora Ink Jet ou Laser colorida
# - Papel A4
# - Plástico Polaseal para plastificação do crachá
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 12893
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 12893
#             - Tokens Top-50: 61952
#             - Economia: 79.19%
#
#
# 🔍 Processando pergunta 6: "De acordo com a Resolução CNS nº 466/2012, item II.21, como é definido o termo 'ressarcimento' no contexto da compensação material em pesquisas?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A Resolução CNS n° 466/2012, item II.21 define ressarcimento como “compensação material, exclusivamente de despesas do participante e seus acompanhantes, quando necessário, tais como transporte e alimentação”.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 6 ====================================================================================================
# Resposta: A Resolução CNS n° 466/2012, item II.21 define ressarcimento como “compensação material, exclusivamente de despesas do participante e seus acompanhantes, quando necessário, tais como transporte e alimentação”.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 8387
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 8387
#             - Tokens Top-50: 55673
#             - Economia: 84.94%
#
#
# 🔍 Processando pergunta 7: "Quais formulários são utilizados na rotina de monitorias remotas descrita no documento, e para que propósito cada um serve?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os formulários utilizados na rotina de monitorias remotas descrita no documento são:
#
# 1. **Formulário CPC – 003 Anuência para Monitoria Remota**: Utilizado pela Chefia do Setor de Pesquisa e Inovações Tecnológicas em Saúde para documentar sua anuência sempre que se tornar necessário realizar monitoria remota, devido às restrições da pandemia de COVID-19. Este formulário fica arquivado nos documentos do Centro de Pesquisa Clínica (CPC) para cobrir todas as atividades subsequentes.
#
# 2. **Formulário CPC – 004 Ciência para Monitoria Remota**: Utilizado por todos os investigadores e sub-investigadores que necessitarem realizar a monitoria remota para deixar documentada sua ciência, respaldando a execução da monitoria.
#
# 3. **Formulário CPC – 005 Acordo de Confidencialidade: Monitoria Remota por vídeo ou webconferência**: Utilizado pelo monitor, que deve encaminhá-lo assinado ao CPC 24 horas antes da monitoria remota. Este formulário compromete o monitor a utilizar a documentação-fonte de forma adequada, destruir de forma segura qualquer cópia de documento-fonte após a verificação dos dados e a não fazer cópias ou gravações de qualquer documento-fonte contendo informações do participante.
#
# Além disso, no relatório de cada monitoria remota, o monitor deve especificar o método utilizado, os documentos verificados e reafirmar que todos os documentos-fonte foram utilizados de forma adequada e que não há arquivos ou gravações referentes aos mesmos.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 7 ====================================================================================================
# Resposta: Os formulários utilizados na rotina de monitorias remotas descrita no documento são:
#
# 1. **Formulário CPC – 003 Anuência para Monitoria Remota**: Utilizado pela Chefia do Setor de Pesquisa e Inovações Tecnológicas em Saúde para documentar sua anuência sempre que se tornar necessário realizar monitoria remota, devido às restrições da pandemia de COVID-19. Este formulário fica arquivado nos documentos do Centro de Pesquisa Clínica (CPC) para cobrir todas as atividades subsequentes.
#
# 2. **Formulário CPC – 004 Ciência para Monitoria Remota**: Utilizado por todos os investigadores e sub-investigadores que necessitarem realizar a monitoria remota para deixar documentada sua ciência, respaldando a execução da monitoria.
#
# 3. **Formulário CPC – 005 Acordo de Confidencialidade: Monitoria Remota por vídeo ou webconferência**: Utilizado pelo monitor, que deve encaminhá-lo assinado ao CPC 24 horas antes da monitoria remota. Este formulário compromete o monitor a utilizar a documentação-fonte de forma adequada, destruir de forma segura qualquer cópia de documento-fonte após a verificação dos dados e a não fazer cópias ou gravações de qualquer documento-fonte contendo informações do participante.
#
# Além disso, no relatório de cada monitoria remota, o monitor deve especificar o método utilizado, os documentos verificados e reafirmar que todos os documentos-fonte foram utilizados de forma adequada e que não há arquivos ou gravações referentes aos mesmos.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 11669
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 11669
#             - Tokens Top-50: 51499
#             - Economia: 77.34%
#
#
# 🔍 Processando pergunta 8: "De acordo com o documento, qual a responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: De acordo com o documento, a responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna é:
#
# - Elaborar o projeto básico de capacitação para instrutoria interna, conforme capacitação validada no PDC.
# - Justificar e encaminhar à UDP as demandas de capacitações extemporâneas.
# - Preencher, no sistema SEI, o Formulário SEI_Projeto Básico de Capacitação, conforme orientações do PDC vigente.
# - Assinar o Projeto Básico e providenciar a assinatura do assistente, chefia da área demandante e demais responsáveis, conforme definido no PDC vigente.
# - Emitir despacho detalhando os papéis e perfis esperados para a execução da ação de capacitação, contendo nome do colaborador indicado, seu cargo e breve justificativa sobre sua qualificação para a temática.
# - Assinar o despacho e providenciar as assinaturas da chefia imediata e demais responsáveis, conforme definido no PDC vigente; no caso de comissão, incluir assinatura do coordenador da comissão e do superintendente.
# - Enviar, via sistema SEI, o projeto com 60 dias de antecedência à realização da ação à unidade UDP/DIVGP/GAD/HE-UFPel e aguardar a elaboração da nota técnica de aprovação ou despacho preliminar.
# - Realizar os ajustes necessários solicitados no processo em, no máximo, 5 dias após o envio do despacho pela UDP.
# - Revisar, quando for o caso, o material didático da capacitação.
# - Providenciar o espaço físico adequado para capacitações presenciais.
# - Providenciar o link da sala virtual para divulgação em capacitações on-line síncronas.
# - Solicitar ao conteudista a inclusão do material produzido e materiais de referência para capacitações à distância e assíncronas na Plataforma 3EC.
# - Acompanhar a execução da capacitação e disponibilizar o link da lista de presença e avaliação de reação aos participantes durante o evento.
# - É responsabilidade do coordenador disponibilizar o link somente para os participantes do evento.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 8 ====================================================================================================
# Resposta: De acordo com o documento, a responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna é:
#
# - Elaborar o projeto básico de capacitação para instrutoria interna, conforme capacitação validada no PDC.
# - Justificar e encaminhar à UDP as demandas de capacitações extemporâneas.
# - Preencher, no sistema SEI, o Formulário SEI_Projeto Básico de Capacitação, conforme orientações do PDC vigente.
# - Assinar o Projeto Básico e providenciar a assinatura do assistente, chefia da área demandante e demais responsáveis, conforme definido no PDC vigente.
# - Emitir despacho detalhando os papéis e perfis esperados para a execução da ação de capacitação, contendo nome do colaborador indicado, seu cargo e breve justificativa sobre sua qualificação para a temática.
# - Assinar o despacho e providenciar as assinaturas da chefia imediata e demais responsáveis, conforme definido no PDC vigente; no caso de comissão, incluir assinatura do coordenador da comissão e do superintendente.
# - Enviar, via sistema SEI, o projeto com 60 dias de antecedência à realização da ação à unidade UDP/DIVGP/GAD/HE-UFPel e aguardar a elaboração da nota técnica de aprovação ou despacho preliminar.
# - Realizar os ajustes necessários solicitados no processo em, no máximo, 5 dias após o envio do despacho pela UDP.
# - Revisar, quando for o caso, o material didático da capacitação.
# - Providenciar o espaço físico adequado para capacitações presenciais.
# - Providenciar o link da sala virtual para divulgação em capacitações on-line síncronas.
# - Solicitar ao conteudista a inclusão do material produzido e materiais de referência para capacitações à distância e assíncronas na Plataforma 3EC.
# - Acompanhar a execução da capacitação e disponibilizar o link da lista de presença e avaliação de reação aos participantes durante o evento.
# - É responsabilidade do coordenador disponibilizar o link somente para os participantes do evento.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 9533
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 9533
#             - Tokens Top-50: 81644
#             - Economia: 88.32%
#
#
# 🔍 Processando pergunta 9: "Qual o prazo que o colaborador apto para a instrutoria interna tem, após o recebimento do despacho de indicação pela UDP, para manifestar confirmação ou indisponibilidade,  e o que precisa ser feito?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Após recebimento do despacho de indicação pela UDP, o colaborador apto para a instrutoria interna tem o prazo de 7 dias para manifestar confirmação ou indisponibilidade, mediante preenchimento do Termo de Ciência da Atividade de Instrutoria Interna_SEI (com a assinatura do instrutor e chefia imediata dele), ou despacho informando a indisponibilidade para atuação na ação de capacitação.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 9 ====================================================================================================
# Resposta: Após recebimento do despacho de indicação pela UDP, o colaborador apto para a instrutoria interna tem o prazo de 7 dias para manifestar confirmação ou indisponibilidade, mediante preenchimento do Termo de Ciência da Atividade de Instrutoria Interna_SEI (com a assinatura do instrutor e chefia imediata dele), ou despacho informando a indisponibilidade para atuação na ação de capacitação.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 17541
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 17541
#             - Tokens Top-50: 86366
#             - Economia: 79.69%
#
#
# 🔍 Processando pergunta 10: "Quais são os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH)?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH) são:
#
# - Norma Operacional de Instrutoria vigente.
# - Portaria SEI nº 2931/2022/DGP-EBSERH.
# - Norma - SEI nº 5/2022/DGP-EBSERH.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 10 ====================================================================================================
# Resposta: Os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH) são:
#
# - Norma Operacional de Instrutoria vigente.
# - Portaria SEI nº 2931/2022/DGP-EBSERH.
# - Norma - SEI nº 5/2022/DGP-EBSERH.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 8831
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 8831
#             - Tokens Top-50: 66971
#             - Economia: 86.81%
#
#
# 🔍 Processando pergunta 11: "De acordo com o documento, qual o procedimento a ser adotado pelo NAA quando a escala de trabalho é recebida após o dia 15 do mês antecedente à escala de referência?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Quando a escala de trabalho for recebida pela DIVGP após o dia 15 do mês antecedente à escala de referência, o NAA deverá incluí-la no bloco interno do SEI em pasta previamente criada com o mês correspondente, nomeando-o através do ícone anotações com a informação da unidade correspondente e informando “Fora do Prazo”. Deve baixar a escala contida no processo, que deverá estar em formato PDF, e arquivá-la em: Computador>NAA>Escalas Mensais>Ano Correspondente>Pasta da Unidade Correspondente. A escala salva deverá ser nomeada da seguinte forma: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022. Será devolvido ao gestor o processo contendo a escala recebida com despacho utilizando texto padrão contido no SEI “Entrega de Escala Fora do Prazo”.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 11 ====================================================================================================
# Resposta: Quando a escala de trabalho for recebida pela DIVGP após o dia 15 do mês antecedente à escala de referência, o NAA deverá incluí-la no bloco interno do SEI em pasta previamente criada com o mês correspondente, nomeando-o através do ícone anotações com a informação da unidade correspondente e informando “Fora do Prazo”. Deve baixar a escala contida no processo, que deverá estar em formato PDF, e arquivá-la em: Computador>NAA>Escalas Mensais>Ano Correspondente>Pasta da Unidade Correspondente. A escala salva deverá ser nomeada da seguinte forma: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022. Será devolvido ao gestor o processo contendo a escala recebida com despacho utilizando texto padrão contido no SEI “Entrega de Escala Fora do Prazo”.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 16880
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 16880
#             - Tokens Top-50: 71390
#             - Economia: 76.36%
#
#
# 🔍 Processando pergunta 12: "Descreva o procedimento para o tratamento de inconsistências encontradas nas escalas de trabalho, especificando as ações das chefias, os formulários utilizados e os departamentos envolvidos no processo de correção."
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-10 chunks
# Resposta: As informações explicitamente contidas nos documentos fornecidos indicam o seguinte procedimento para o tratamento de inconsistências encontradas nas escalas de trabalho, incluindo as ações das chefias, os formulários utilizados e os departamentos envolvidos:
#
# 1. **Identificação das inconsistências:**
#    - O Núcleo de Apoio Assistencial (NAA) recebe as escalas de trabalho em PDF enviadas pelos gestores via processo SEI.
#    - O NAA verifica as escalas quanto à conformidade com a Norma Operacional DGP Nº 04/2017, incluindo dados obrigatórios (logotipo, nome da unidade, nome completo do empregado, SIAPE, registro profissional, cargo, vínculo, carga horária semanal, intervalos).
#    - Verifica se o horário individual do empregado cadastrado no sistema SIGP/Mentorh é o mesmo descrito na escala de trabalho.
#    - Caso haja divergência entre o horário cadastrado e o descrito na escala, é considerada uma inconsistência.
#    - Também é verificado se foi contemplado o Descanso Semanal Remunerado (DSR) após seis dias consecutivos de trabalho.
#
# 2. **Ações das chefias em relação às inconsistências:**
#    - Quando identificadas inconsistências, a escala será devolvida ao gestor para as devidas retificações.
#    - As alterações nos horários individuais dos empregados devem ser solicitadas pelo gestor através do **Formulário de Alteração de Horário Individual**, disponível no SEI.
#    - O formulário deve ser encaminhado para a **Unidade de Administração de Pessoal (UAP)**, especificamente para UAP/DIVGP/GA/HE-UFPEL.
#    - O formulário deve conter informações detalhadas de cada empregado: nome completo, SIAPE, horários que o empregado deverá realizar em cada dia da semana e data de início da nova jornada de trabalho.
#
# 3. **Prazos e procedimentos adicionais:**
#    - O gestor tem prazo para retorno da escala corrigida: 96 horas para a Divisão de Enfermagem e 72 horas para as demais unidades.
#    - Caso a escala seja entregue após o dia 15 do mês antecedente, será arquivada pelo NAA e o cadastramento dos horários ficará sob responsabilidade do gestor.
#    - Se houver troca de plantão/horário após o cadastramento, o gestor deve lançar as alterações no sistema SIGP e encaminhar a escala atualizada via despacho para arquivamento.
#
# 4. **Departamentos envolvidos:**
#    - Núcleo de Apoio Assistencial (NAA): Recebe, verifica e devolve escalas com inconsistências.
#    - Unidade de Administração de Pessoal (UAP): Recebe o Formulário de Alteração de Horário Individual para efetuar as correções no sistema.
#    - Chefias imediatas/gestores: Responsáveis por elaborar as escalas, solicitar correções e encaminhar formulários.
#    - Divisão de Gestão de Pessoas (DIVGP): Recebe as escalas via SEI e acompanha o processo.
#
# **Resumo dos formulários utilizados:**
# - **Formulário de Alteração de Horário Individual** (disponível no SEI): utilizado para solicitar alterações nos horários individuais dos empregados.
#
# ---
#
# **Resposta resumida:**
#
# O Núcleo de Apoio Assistencial (NAA) recebe as escalas de trabalho em PDF via processo SEI e verifica a conformidade dos dados e a compatibilidade dos horários individuais com o sistema SIGP/Mentorh. Caso sejam encontradas inconsistências, a escala é devolvida ao gestor para correção. O gestor deve solicitar as alterações nos horários individuais por meio do Formulário de Alteração de Horário Individual, disponível no SEI, que deve ser encaminhado para a Unidade de Administração de Pessoal (UAP). O gestor tem prazo para retorno da escala corrigida (96 horas para enfermagem e 72 horas para outras unidades). Após correção, o gestor deve atualizar o sistema SIGP e enviar a escala atualizada para arquivamento. As chefias são responsáveis por elaborar as escalas, solicitar correções e acompanhar o processo, enquanto o NAA e a UAP são os departamentos envolvidos na verificação e correção das escalas.
# ✔ Validação: False
# ❌ Falso positivo, continuando...
#
# 🔎 Testando com top-15 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-20 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-25 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-30 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-35 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-40 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-45 chunks
# Resposta: NÃO ENCONTRADO
#
# 🔎 Testando com top-50 chunks
# Resposta: NÃO ENCONTRADO
#
# ==================================================================================================== RESPOSTA 12 ====================================================================================================
# Resposta: NÃO ENCONTRADO
# k_utilizado: 50
# num_chamadas: 11
# tokens_estimados: 338281
# status: FALHA
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 338281
#             - Tokens Top-50: 51886
#             - Economia: -551.97%
#
#
# 🔍 Processando pergunta 13: "Quais são os passos para inserir as escalas de trabalho nas pastas, após a criação das pastas anuais e mensais, de acordo com as instruções fornecidas?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os passos para inserir as escalas de trabalho nas pastas, após a criação das pastas anuais e mensais, de acordo com as instruções fornecidas, são:
#
# 1. Ao receber o processo contendo as escalas de trabalho, o NAA incluirá o processo no bloco interno do SEI em pasta previamente criada com o mês correspondente, nomeando-o através do ícone anotações com a informação da unidade correspondente.
#
# 2. Baixar a escala contida no processo, que deverá estar em formato PDF.
#
# 3. Arquivar a escala no caminho: Computador > NAA > Escalas Mensais > Ano Correspondente > Pasta da Unidade Correspondente.
#
# 4. Nomear a escala salva da seguinte forma: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022.
#
# Esses passos estão descritos nos Documentos 1 e 2.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 13 ====================================================================================================
# Resposta: Os passos para inserir as escalas de trabalho nas pastas, após a criação das pastas anuais e mensais, de acordo com as instruções fornecidas, são:
#
# 1. Ao receber o processo contendo as escalas de trabalho, o NAA incluirá o processo no bloco interno do SEI em pasta previamente criada com o mês correspondente, nomeando-o através do ícone anotações com a informação da unidade correspondente.
#
# 2. Baixar a escala contida no processo, que deverá estar em formato PDF.
#
# 3. Arquivar a escala no caminho: Computador > NAA > Escalas Mensais > Ano Correspondente > Pasta da Unidade Correspondente.
#
# 4. Nomear a escala salva da seguinte forma: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022.
#
# Esses passos estão descritos nos Documentos 1 e 2.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 16868
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 16868
#             - Tokens Top-50: 60866
#             - Economia: 72.29%
#
#
# 🔍 Processando pergunta 14: "Qual o procedimento descrito no documento para anexar a Declaração de Dispensa no sistema SEI UFPel, após o preenchimento do formulário PROGEP: Requerimento de Benefícios?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Após o preenchimento do formulário PROGEP: Requerimento de Benefícios, para anexar a Declaração de Dispensa no sistema SEI UFPel, deve-se:
#
# 1. Selecionar a opção “Incluir Documento” e escolher o Tipo do Documento: “Externo”;
# 2. Na próxima tela, preencher o Tipo do Documento: “Declaração”, a data do documento, o Número/Nome na Árvore: “Justiça Eleitoral”, o formato, o nível de acesso e a hipótese legal;
# 3. Anexar o arquivo da Declaração de Dispensa, procurando o mesmo nos seus documentos;
# 4. Após concluído, clicar em “Confirmar Dados”;
# 5. Depois de preencher e assinar o formulário PROGEP: Requerimento de Benefícios e incluir o anexo com a Declaração de Dispensa, o servidor deve informar o número do processo para a chefia da Unidade que deverá assinar o documento;
# 6. Após a assinatura da chefia, o servidor deve enviar o processo para a Seção de Apoio Administrativo – SAAD/PROGEP;
# 7. Após enviar ao SAAD, o servidor deve acompanhar o processo para conferir se a folga foi autorizada e lançada pela PROGEP.
#
# IMPORTANTE: A folga deve ser autorizada pela chefia e o processo enviado à SAAD ANTES da data prevista para o gozo da folga.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 14 ====================================================================================================
# Resposta: Após o preenchimento do formulário PROGEP: Requerimento de Benefícios, para anexar a Declaração de Dispensa no sistema SEI UFPel, deve-se:
#
# 1. Selecionar a opção “Incluir Documento” e escolher o Tipo do Documento: “Externo”;
# 2. Na próxima tela, preencher o Tipo do Documento: “Declaração”, a data do documento, o Número/Nome na Árvore: “Justiça Eleitoral”, o formato, o nível de acesso e a hipótese legal;
# 3. Anexar o arquivo da Declaração de Dispensa, procurando o mesmo nos seus documentos;
# 4. Após concluído, clicar em “Confirmar Dados”;
# 5. Depois de preencher e assinar o formulário PROGEP: Requerimento de Benefícios e incluir o anexo com a Declaração de Dispensa, o servidor deve informar o número do processo para a chefia da Unidade que deverá assinar o documento;
# 6. Após a assinatura da chefia, o servidor deve enviar o processo para a Seção de Apoio Administrativo – SAAD/PROGEP;
# 7. Após enviar ao SAAD, o servidor deve acompanhar o processo para conferir se a folga foi autorizada e lançada pela PROGEP.
#
# IMPORTANTE: A folga deve ser autorizada pela chefia e o processo enviado à SAAD ANTES da data prevista para o gozo da folga.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 14093
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 14093
#             - Tokens Top-50: 91799
#             - Economia: 84.65%
#
#
# 🔍 Processando pergunta 15: "Quais são os passos necessários para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, incluindo as ações para alteração de lotação e vacância?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os passos necessários para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, incluindo as ações para alteração de lotação e vacância, são:
#
# 1. Cadastro de servidores no SIP:
#    - Acessar o sistema SIP e clicar em “Usuários” + “Novo”.
#    - Incluir os dados solicitados:
#      - Orgão: HE-UFPEL
#      - Sigla: usuário do servidor (usuário de acesso aos sistemas EBSERH e/ou e-mail EBSERH)
#      - Nome: nome completo do servidor
#      - ID Origem: (em branco)
#    - Salvar.
#
# 2. Cadastro de Permissões:
#    - Clicar em “Permissões” + “Nova”.
#    - Preencher os campos:
#      - Orgão do Sistema: SEDE
#      - Sistema: SEI
#      - Orgão da Unidade: HE-UFPEL
#      - Orgão do Usuário: HE-UFPEL
#      - Perfil: Básica
#      - Unidade: cadastrar a unidade do servidor
#      - Usuário: cadastrar a sigla do servidor (nome.sobrenome)
#    - Salvar.
#
# 3. Em caso de alteração na unidade de lotação:
#    - Incluir a data final na permissão vigente.
#    - Cadastrar nova permissão para o usuário.
#
# 4. Em caso de vacância:
#    - Incluir a data final na permissão vigente.
#
# Referência do sistema SIP para acesso: https://sei.ebserh.gov.br/sip/login.php?sigla_orgao_sistema=SEDE&sigla_sistema=SIP&infra_url=L3NpcC8/
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 15 ====================================================================================================
# Resposta: Os passos necessários para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, incluindo as ações para alteração de lotação e vacância, são:
#
# 1. Cadastro de servidores no SIP:
#    - Acessar o sistema SIP e clicar em “Usuários” + “Novo”.
#    - Incluir os dados solicitados:
#      - Orgão: HE-UFPEL
#      - Sigla: usuário do servidor (usuário de acesso aos sistemas EBSERH e/ou e-mail EBSERH)
#      - Nome: nome completo do servidor
#      - ID Origem: (em branco)
#    - Salvar.
#
# 2. Cadastro de Permissões:
#    - Clicar em “Permissões” + “Nova”.
#    - Preencher os campos:
#      - Orgão do Sistema: SEDE
#      - Sistema: SEI
#      - Orgão da Unidade: HE-UFPEL
#      - Orgão do Usuário: HE-UFPEL
#      - Perfil: Básica
#      - Unidade: cadastrar a unidade do servidor
#      - Usuário: cadastrar a sigla do servidor (nome.sobrenome)
#    - Salvar.
#
# 3. Em caso de alteração na unidade de lotação:
#    - Incluir a data final na permissão vigente.
#    - Cadastrar nova permissão para o usuário.
#
# 4. Em caso de vacância:
#    - Incluir a data final na permissão vigente.
#
# Referência do sistema SIP para acesso: https://sei.ebserh.gov.br/sip/login.php?sigla_orgao_sistema=SEDE&sigla_sistema=SIP&infra_url=L3NpcC8/
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 18364
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 18364
#             - Tokens Top-50: 67749
#             - Economia: 72.89%
#
#
# 🔍 Processando pergunta 16: "Qual o prazo de entrega do formulário DIVGP – DASF – 001 Remanejamento Interno RJU ao Departamento de Apoio ao Servidor Federal (DivGP), contado a partir da data da efetiva mudança de lotação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: O formulário DIVGP – DASF – 001 Remanejamento Interno RJU deve ser entregue no Departamento de Apoio ao Servidor Federal (DivGP) com 15 dias de antecedência da efetiva mudança de lotação.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 16 ====================================================================================================
# ...
#
# Além disso, é necessário possuir o Comprovante de Dispensa fornecido pela Justiça Eleitoral.
#
# Essas informações estão explicitamente contidas nos Documentos 1, 2 e 3.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 187 ====================================================================================================
# Resposta: Para solicitar uma folga eleitoral, deve-se seguir o procedimento via SEI UFPel conforme descrito nos documentos:
#
# 1. Fazer login no SEI UFPel (https://sei.ufpel.edu.br) com usuário (CPF) e senha.
# 2. Clicar em “Iniciar Processo” e escolher o Tipo do Processo: “Pessoal: Dispensa por serviço prestado à Justiça Eleitoral (TRE)”.
# 3. No campo “Especificação” digitar o nome do servidor e no campo “Nível de Acesso” selecionar a opção “restrito” com a hipótese legal, e clicar em “Salvar”.
# 4. Na próxima página, selecionar “Incluir Documento” e escolher o Tipo do Documento: “PROGEP: Requerimento de Benefícios”.
# 5. Na próxima tela, no campo “Nível de Acesso” selecionar “restrito” com a hipótese legal, e clicar em “Confirmar Dados”.
# 6. Preencher o documento com os dados pessoais do servidor e selecionar o benefício requerido: “Ausência serviço prestado Justiça Eleitoral”, informando a data da folga solicitada.
# 7. Clicar em “salvar” e “assinar” o documento.
# 8. Anexar a Declaração de Dispensa fornecida pela Justiça Eleitoral, selecionando “Incluir Documento” e escolhendo o Tipo do Documento: “Externo”, preenchendo os dados e anexando o arquivo.
# 9. Informar o número do processo para a chefia da Unidade que deverá assinar o documento.
# 10. Após a assinatura da chefia, enviar o processo para a Seção de Apoio Administrativo – SAAD/PROGEP.
# 11. Acompanhar o processo para conferir se a folga foi autorizada e lançada pela PROGEP.
#
# Importante: A folga deve ser autorizada pela chefia e o processo enviado à SAAD antes da data prevista para o gozo da folga.
#
# Além disso, é necessário possuir o Comprovante de Dispensa fornecido pela Justiça Eleitoral.
#
# Essas informações estão explicitamente contidas nos Documentos 1, 2 e 3.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 7875
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 7875
#             - Tokens Top-50: 87863
#             - Economia: 91.04%
#
#
# 🔍 Processando pergunta 188: "Como formalizar a troca de unidade ( lotação) por servidores no Hospital Escola?
#
# "
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para formalizar a troca de unidade (lotação) por servidores no Hospital Escola, deve-se seguir o procedimento descrito no Documento 1:
#
# 1. A chefia de origem deve imprimir o formulário DIVGP – DASF – 001 Remanejamento Interno RJU, disponível no sistema ADS Hospitalar, aba documentos, pasta DIVGP / DASF.
# 2. O formulário deve ser preenchido com os dados solicitados, incluindo a manifestação do servidor, da chefia imediata e da chefia de destino, informando a data do remanejamento e os horários que serão realizados pelo servidor.
# 3. Após o preenchimento e assinatura dos envolvidos, o formulário deve ser entregue no Departamento de Apoio ao Servidor Federal (DivGP) com 15 dias de antecedência da efetiva mudança de lotação.
# 4. No momento do recebimento do formulário, o responsável pelo Departamento de Apoio ao Servidor Federal deverá realizar as atualizações necessárias em seus controles internos.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 188 ====================================================================================================
# Resposta: Para formalizar a troca de unidade (lotação) por servidores no Hospital Escola, deve-se seguir o procedimento descrito no Documento 1:
#
# 1. A chefia de origem deve imprimir o formulário DIVGP – DASF – 001 Remanejamento Interno RJU, disponível no sistema ADS Hospitalar, aba documentos, pasta DIVGP / DASF.
# 2. O formulário deve ser preenchido com os dados solicitados, incluindo a manifestação do servidor, da chefia imediata e da chefia de destino, informando a data do remanejamento e os horários que serão realizados pelo servidor.
# 3. Após o preenchimento e assinatura dos envolvidos, o formulário deve ser entregue no Departamento de Apoio ao Servidor Federal (DivGP) com 15 dias de antecedência da efetiva mudança de lotação.
# 4. No momento do recebimento do formulário, o responsável pelo Departamento de Apoio ao Servidor Federal deverá realizar as atualizações necessárias em seus controles internos.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 7991
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 7991
#             - Tokens Top-50: 70337
#             - Economia: 88.64%
#
#
# 🔍 Processando pergunta 189: "quem pode fazer as inspeções de OLA?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A aplicação das inspeções, bem como as avaliações são feitas exclusivamente por profissionais da USOST. É facultado às chefias dos locais ou serviços avaliados o acompanhamento durante a realização das inspeções. Poderá a chefia designar outro profissional para acompanhamento.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 189 ====================================================================================================
# Resposta: A aplicação das inspeções, bem como as avaliações são feitas exclusivamente por profissionais da USOST. É facultado às chefias dos locais ou serviços avaliados o acompanhamento durante a realização das inspeções. Poderá a chefia designar outro profissional para acompanhamento.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 7786
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 7786
#             - Tokens Top-50: 41570
#             - Economia: 81.27%
#
#
# 🔍 Processando pergunta 190: "o que fazer em relação da rotulagem dos produtos quimicos?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: De acordo com o Documento 1 e outros documentos relacionados, em relação à rotulagem dos produtos químicos deve-se:
#
# - Manter a rotulagem do fabricante na embalagem original dos produtos químicos utilizados em serviços de saúde.
# - Todo recipiente contendo produto químico manipulado ou fracionado deve ser identificado, de forma legível, por etiqueta com o nome do produto, composição química, sua concentração, data de envase e de validade, e nome do responsável pela manipulação ou fracionamento.
# - É vedado o procedimento de reutilização das embalagens de produtos químicos, exceto quando admitido pelo fabricante.
# - Manter rotulada toda embalagem de produto químico fracionado.
# - Caso a embalagem de algum produto químico esteja sem rotulagem original ou avariada, o recebimento deste deve ser recusado e a chefia imediata deve ser comunicada imediatamente.
#
# Essas orientações garantem a correta identificação e segurança no manuseio dos produtos químicos.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 190 ====================================================================================================
# Resposta: De acordo com o Documento 1 e outros documentos relacionados, em relação à rotulagem dos produtos químicos deve-se:
#
# - Manter a rotulagem do fabricante na embalagem original dos produtos químicos utilizados em serviços de saúde.
# - Todo recipiente contendo produto químico manipulado ou fracionado deve ser identificado, de forma legível, por etiqueta com o nome do produto, composição química, sua concentração, data de envase e de validade, e nome do responsável pela manipulação ou fracionamento.
# - É vedado o procedimento de reutilização das embalagens de produtos químicos, exceto quando admitido pelo fabricante.
# - Manter rotulada toda embalagem de produto químico fracionado.
# - Caso a embalagem de algum produto químico esteja sem rotulagem original ou avariada, o recebimento deste deve ser recusado e a chefia imediata deve ser comunicada imediatamente.
#
# Essas orientações garantem a correta identificação e segurança no manuseio dos produtos químicos.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 12994
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 12994
#             - Tokens Top-50: 56478
#             - Economia: 76.99%
#
#
# 🔍 Processando pergunta 191: "o que fazer se eu me acidentar durante o uso de produtos quimicos?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: As ações de emergência pós exposição pessoal a produtos químicos variam de acordo com cada produto, por isso devem ser seguidas as instruções contidas em suas respectivas Fichas de Informação de Segurança de Produtos Químicos. O médico deverá ser consultado imediatamente ou o mais breve possível.
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 191 ====================================================================================================
# Resposta: As ações de emergência pós exposição pessoal a produtos químicos variam de acordo com cada produto, por isso devem ser seguidas as instruções contidas em suas respectivas Fichas de Informação de Segurança de Produtos Químicos. O médico deverá ser consultado imediatamente ou o mais breve possível.
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 6970
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6970
#             - Tokens Top-50: 62778
#             - Economia: 88.90%
#
#
# 🔍 Processando pergunta 192: "Estou me sentindo ansioso e sobre carregado. como faço para pedir ajuda? "
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para pedir ajuda ao se sentir ansioso e sobrecarregado, o colaborador deve entrar em contato com o enfermeiro de saúde mental através do e-mail sm.usost.he-ufpel@ebserh.gov.br ou pelo Ramal 5166. O enfermeiro de saúde mental consultará e agendará com o colaborador o dia, horário e local para a realização da escuta qualificada, que é uma escuta empática para acolher as necessidades emocionais do colaborador e possibilitar encaminhamentos adequados para avaliação dos demais profissionais da equipe do canal de saúde mental, composta por Psiquiatra, Psicólogas, Médicas do trabalho, entre outros. Caso o colaborador não possa comparecer na data marcada, a escuta será reagendada. Em caso de ausência não justificada, será feito novo contato para consultar o interesse no serviço especializado; se o colaborador não aceitar, o acolhimento será finalizado com registro em prontuário.
#
# Além disso, a chefia imediata será informada de forma sigilosa sobre o acolhimento para que possa acompanhar o processo e orientar o colaborador.
#
# (Informações extraídas dos Documentos 2, 3 e 4, seção 3.3.)
# ✔ Validação: True
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 192 ====================================================================================================
# Resposta: Para pedir ajuda ao se sentir ansioso e sobrecarregado, o colaborador deve entrar em contato com o enfermeiro de saúde mental através do e-mail sm.usost.he-ufpel@ebserh.gov.br ou pelo Ramal 5166. O enfermeiro de saúde mental consultará e agendará com o colaborador o dia, horário e local para a realização da escuta qualificada, que é uma escuta empática para acolher as necessidades emocionais do colaborador e possibilitar encaminhamentos adequados para avaliação dos demais profissionais da equipe do canal de saúde mental, composta por Psiquiatra, Psicólogas, Médicas do trabalho, entre outros. Caso o colaborador não possa comparecer na data marcada, a escuta será reagendada. Em caso de ausência não justificada, será feito novo contato para consultar o interesse no serviço especializado; se o colaborador não aceitar, o acolhimento será finalizado com registro em prontuário.
#
# Além disso, a chefia imediata será informada de forma sigilosa sobre o acolhimento para que possa acompanhar o processo e orientar o colaborador.
#
# (Informações extraídas dos Documentos 2, 3 e 4, seção 3.3.)
# k_utilizado: 5
# num_chamadas: 2
# tokens_estimados: 35648
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 35648
#             - Tokens Top-50: 138679
#             - Economia: 74.29%
#
#
# 📋 DataFrame - Respostas
#                                             pergunta  \
# 0  Quais formulários são mencionados no documento...
# 1  De acordo com o documento, qual é a definição ...
# 2  Quais são os materiais necessários para a form...
# 3  Quais são os materiais necessários para o pree...
# 4  Quais são os materiais necessários para o pree...
#
#                                             resposta  k_utilizado  \
# 0  Os formulários mencionados no documento como d...            5
# 1  De acordo com o documento 1 (e também repetido...            5
# 2  Os materiais necessários para a formalização d...            5
# 3  Os materiais necessários para o preenchimento ...            5
# 4  Os materiais necessários para o preenchimento ...            5
#
#    num_chamadas  tokens_incremental  tokens_top50  economia_tokens   status
# 0             2                7517        101735         0.926112  SUCESSO
# 1             2               10150         66961         0.848419  SUCESSO
# 2             2               10164         80746         0.874124  SUCESSO
# 3             2               13345         60405         0.779075  SUCESSO
# 4             2               12893         61952         0.791887  SUCESSO
#
# ✅ Todas as perguntas foram processadas.

# %%
# Avaliação respostas geradas com BertScore
import pandas as pd
from bert_score import score

# --- BLOCO DE EXECUÇÃO PRINCIPAL ---
if __name__ == "__main__":
    
    # --------------------------------------------------------------
    # 1) Carrega as respostas de referência (gabarito) do CSV
    # --------------------------------------------------------------
    df_gabarito = pd.read_csv("perguntas_respostas_unificadas.xls")

    # Converte tudo para string e remove NaN
    df_gabarito["resposta"] = df_gabarito["resposta"].fillna("").astype(str)

    respostas_referencia = df_gabarito["resposta"].tolist()
    

    # --------------------------------------------------------------
    # 2) Carrega as respostas geradas pelo re-ranker
    # --------------------------------------------------------------
    df_respostas_rff = pd.read_csv(
        "resultados_incremental_gpt4_1mini.csv"
    )

    # Converte para string
    df_respostas_rff["resposta"] = df_respostas_rff["resposta"].fillna("").astype(str)


    # Verificação de segurança
    if len(df_respostas_rff) != len(respostas_referencia):
        print(f"⚠️ Aviso: número de respostas não bate! {len(df_respostas_rff)} vs {len(respostas_referencia)}")
    
    # Ajustar tamanho mínimo comum
    n = min(len(df_respostas_rff), len(respostas_referencia))

    respostas_geradas = df_respostas_rff["resposta"].iloc[:n].tolist()
    referencias = respostas_referencia[:n]


    # --------------------------------------------------------------
    # 3) Calcula BERTScore
    # --------------------------------------------------------------
    print("Calculando BERTScore...")
    P, R, F1 = score(respostas_geradas, referencias, lang="pt", verbose=True)


    # --------------------------------------------------------------
    # 4) Monta DataFrame com resultados
    # --------------------------------------------------------------
    df_resultados = pd.DataFrame({
        "resposta_gerada": respostas_geradas,
        "resposta_referencia": referencias,
        "precision": P.tolist(),
        "recall": R.tolist(),
        "f1": F1.tolist()
    })


    # --------------------------------------------------------------
    # 5) Salva em CSV
    # --------------------------------------------------------------
    df_resultados.to_csv('resultados_bertscore_incremental_gpt4_1mini.csv', index=False)

    print("✅ Arquivo 'resultados_bertscore_incremental_pt4_1mini.csv' salvo com sucesso.")
    print(f"\n✅ Média F1: {F1.mean().item():.4f}")
# Out:
# Calculando BERTScore...
# calculating scores...
# computing bert embedding.
#   0%|          | 0/6 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/3 [00:00<?, ?it/s]
# done in 104.46 seconds, 1.84 sentences/sec
# ✅ Arquivo 'resultados_bertscore_incremental_pt4_1mini.csv' salvo com sucesso.
#
# ✅ Média F1: 0.8083
