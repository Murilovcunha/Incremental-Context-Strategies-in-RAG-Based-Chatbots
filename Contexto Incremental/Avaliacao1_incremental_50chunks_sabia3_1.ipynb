# %%
#Consulta em Duas Etapas (Retrieve & Re-rank):

import psycopg2
import numpy as np
import pandas as pd
import requests
from scipy.spatial.distance import cosine # Importando a distância de cosseno
from sentence_transformers import SentenceTransformer
import json
import tkinter as tk
from tkinter import messagebox
import time
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from sklearn.decomposition import PCA
import matplotlib.patches as patches
import traceback
import re
from sentence_transformers import CrossEncoder
from rank_bm25 import BM25Okapi
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from openai import OpenAI
# Listas globais para armazenar os rankings de todas as chamadas
lista_ids_ordem_cosseno = []
lista_ids_reordenados_int = []

# --- CONFIGURAÇÕES ---
# Inicializar modelo para gerar o embedding da consulta
print("Carregando o modelo de embeddings...")
modelo = SentenceTransformer('intfloat/multilingual-e5-small')
print("Modelo carregado.")



import openai

client = openai.OpenAI(
    api_key="Chave API",
    base_url="https://chat.maritaca.ai/api"
)

MODEL_NAME = "sabia-3.1"

# Configurações do Banco de Dados
DB_HOST = "localhost"
DB_NAME = "postgres" # Nome do banco de dados
DB_USER = "postgres"
DB_PORT = 5432
DB_PASS = "senha" 
DB_TABLE = "texto_avaliacao_ebserh" # Nome da tabela com os dados

# --- FUNÇÕES DE BANCO DE DADOS E LÓGICA DE RAG ---

def buscar_todos_os_dados():
    """Busca todos os dados necessários (id, texto_artigo, vector, texto_pagina) do banco."""
    try:
        conexao = psycopg2.connect(host=DB_HOST, port=DB_PORT, database=DB_NAME, user=DB_USER, password=DB_PASS)
        cursor = conexao.cursor()
        
        # Seleciona todas as colunas que serão usadas no processo
        cursor.execute(f"SELECT id, texto_artigo, vector, texto_pagina, nome_arquivo FROM {DB_TABLE}")
        
        resultados = cursor.fetchall()
        cursor.close()
        conexao.close()
        print(f"Encontrados {len(resultados)} registros no banco de dados.")
        return resultados
    except Exception as e:
        print(f"Erro ao conectar ou buscar dados do banco: {e}")
        return []

def recuperacao_inicial_por_similaridade(query_embedding, dados_banco, k=100):
    """
    Calcula a similaridade de cossenos e retorna os k chunks mais próximos.
    A distância de cosseno é 1 - similaridade de cosseno. Menor distância = maior similaridade.
    """
    # Calcula a distância de cosseno entre a query e todos os embeddings do banco
    # A estrutura de 'dado' agora é (id, texto_artigo, vector, texto_pagina)
    resultados_com_distancia = [
        (dado, cosine(query_embedding, np.array(json.loads(dado[2])).flatten()))
        for dado in dados_banco
    ]
    
    # Ordena pela distância (menor para o maior) e pega os top k
    resultados_ordenados = sorted(resultados_com_distancia, key=lambda x: x[1])[:k]
    
    # Retorna apenas os dados dos chunks, sem a distância
    top_k_chunks = [dado for dado, dist in resultados_ordenados]
    print(f"Recuperação inicial concluída. {len(top_k_chunks)} chunks selecionados.")
    return top_k_chunks
    #print(f"Recuperação inicial concluída. {len(resultados_ordenados)} chunks selecionados a partir de registros válidos.")
    #return resultados_ordenados # Retorna a lista de tuplas (dado, distancia)

def imprimir_rankings_para_comparacao(top_100_chunks, top_100_rrf):
    global lista_ids_ordem_cosseno, lista_ids_reordenados_int

    # 1. Extrai a lista de IDs da busca por cosseno (são inteiros)
    ids_ordem_cosseno = [chunk[0] for chunk in top_100_chunks]
    ids_ordem_rrf = [chunk[0] for chunk in top_100_rrf]
    # 2. Converte os IDs do Gemini (que são strings) para inteiros para uma comparação justa
   # ids_reordenados_int = []
   # for id_str in ids_reordenados:
       # try:
          #  ids_reordenados_int.append(int(id_str))
        #except (ValueError, TypeError):
           # print(f"Aviso: ID '{id_str}' retornado pelo Gemini não é um inteiro e será ignorado.")

    # 3. Armazena os rankings gerados nesta chamada
    lista_ids_ordem_cosseno.append(ids_ordem_cosseno)
    lista_ids_reordenados_int.append(ids_ordem_rrf)

def bm25_rank(top_chunks, query):
    """
    Recebe os 100 chunks recuperados por similaridade de cosseno e realiza reranqueamento com BM25.
    Retorna os mesmos chunks ordenados pela relevância BM25.
    """
    # Extrair os textos dos chunks (ajuste o índice conforme necessário)
    textos = [chunk[1] for chunk in top_chunks]  # Exemplo: chunk[1] é o 'texto_artigo'

    # Tokenização
    corpus_tokenizado = [word_tokenize(doc.lower()) for doc in textos]
    query_tokenizada = word_tokenize(query.lower())

    # Inicializa o modelo BM25
    bm25 = BM25Okapi(corpus_tokenizado)

    # Calcula os scores
    scores = bm25.get_scores(query_tokenizada)

    # Associa cada chunk ao seu score
    chunks_com_score = list(zip(top_chunks, scores))

    # Ordena pelo score decrescente
    rerankeado = sorted(chunks_com_score, key=lambda x: x[1], reverse=True)

    # Retorna só os chunks reranqueados
    return [chunk for chunk, score in rerankeado]

# ======= RRF =======

def rrf_rank(ranking1, ranking2, k=60):
    """
    Aplica Reciprocal Rank Fusion (RRF) nos rankings de chunks.
    Recebe dois rankings (listas de chunks) e retorna uma lista de chunks reranqueada.
    """
    from collections import defaultdict

    # Mapeia IDs para os próprios chunks
    id_para_chunk = {chunk[0]: chunk for chunk in ranking1 + ranking2}

    # Inicializa os scores RRF
    scores_rrf = defaultdict(float)

    # Ranking 1: Similaridade de Cosseno
    for rank, chunk in enumerate(ranking1):
        chunk_id = chunk[0]
        scores_rrf[chunk_id] += 1 / (k + rank)

    # Ranking 2: BM25
    for rank, chunk in enumerate(ranking2):
        chunk_id = chunk[0]
        scores_rrf[chunk_id] += 1 / (k + rank)

    # Ordena os chunks por score RRF
    ids_ordenados = sorted(scores_rrf.items(), key=lambda x: x[1], reverse=True)

    # Retorna a lista de chunks reranqueada
    return [id_para_chunk[chunk_id] for chunk_id, _ in ids_ordenados]


def rag_incremental(query, top_chunks, step=5, max_k=50):
    print("\n🚀 Iniciando RAG Incremental...")

    k = step
    total_tokens = 0
    num_chamadas = 0

    while k <= max_k:
        print(f"\n🔎 Testando com top-{k} chunks")

        subset = top_chunks[:k]

        contexto = [
            {"texto": chunk[3], "fonte": chunk[4]}
            for chunk in subset
        ]

        # Monta prompt (para contar tokens)
        contexto_str = " ".join([c["texto"] for c in contexto])
        prompt_estimado = f"{query} {contexto_str}"

        tokens_prompt = estimar_tokens(prompt_estimado)

        # chamada principal
        resposta = gerar_resposta_incremental_sabia(query, contexto)
        num_chamadas += 1

        tokens_resposta = estimar_tokens(resposta)
        total_tokens += tokens_prompt + tokens_resposta

        print("Resposta:", resposta)

        if "NÃO ENCONTRADO" in resposta:
            k += step
            continue

        # 🔍 verificação
        prompt_verificacao = f"{query} {resposta} {contexto_str}"
        tokens_verificacao_prompt = estimar_tokens(prompt_verificacao)

        valido = verificar_resposta_sabia(query, resposta, contexto)
        num_chamadas += 1

        tokens_verificacao_resposta = estimar_tokens(str(valido))
        total_tokens += tokens_verificacao_prompt + tokens_verificacao_resposta

        print("✔ Validação:", valido)

        if valido:
            print(f"✅ Resposta encontrada com top-{k}")
            return {
                "resposta": resposta,
                "k_utilizado": k,
                "status": "SUCESSO",
                "num_chamadas": num_chamadas,
                "tokens_estimados": total_tokens
            }
        else:
            print("❌ Falso positivo, continuando...")
            k += step

    return {
        "resposta": "NÃO ENCONTRADO",
        "k_utilizado": max_k,
        "status": "FALHA",
        "num_chamadas": num_chamadas,
        "tokens_estimados": total_tokens
    }
  
def gerar_resposta_incremental_sabia(query, chunks):

    contexto = ""

    for i, chunk in enumerate(chunks):
        contexto += f"Documento {i+1}:\n{chunk['texto']}\n\n"

    prompt = f"""
Você é um especialista em análise de documentos.

Sua tarefa é responder à pergunta com base nos textos fornecidos.

⚠️ REGRAS IMPORTANTES:
- Gere UMA ÚNICA resposta final
- NÃO responda por documento
- NÃO escreva "Documento 1", "Documento 2", etc.
- NÃO liste múltiplas respostas separadas
- NÃO repita trechos
- Seja objetiva e direta

- Se a resposta NÃO estiver presente nos textos, responda exatamente:
NÃO ENCONTRADO

Pergunta:
{query}

Textos:
{contexto}
"""

    try:

        response = client.chat.completions.create(
            model=MODEL_NAME,
            messages=[
                {"role": "system", "content": "Você é um assistente especialista em análise de documentos."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.8,
            max_tokens=512
        )

        resposta = response.choices[0].message.content.strip()

        return resposta

    except Exception as e:
        print("❌ Erro Sabiá incremental:", e)
        return "ERRO"
        

def verificar_resposta_sabia(query, resposta, chunks):
    contexto = ""
    for i, chunk in enumerate(chunks):
        contexto += f"Documento {i+1}:\n{chunk['texto']}\n\n"

    prompt = f"""
    A resposta abaixo está REALMENTE suportada pelos documentos?

    Responda apenas com:
    SIM ou NÃO

    Pergunta:
    {query}

    Resposta:
    {resposta}

    Documentos:
    {contexto}
    """

    payload = {
        "contents": [{"parts": [{"text": prompt}]}]
    }

    try:
        response = requests.post(f"{API_URL}?key={API_KEY}",
                                 headers={'Content-Type': 'application/json'},
                                 json=payload)

        data = response.json()
        validacao = data['candidates'][0]['content']['parts'][0]['text'].strip().upper()

        return "SIM" in validacao

    except Exception as e:
        print("Erro verificação:", e)
        return False

def estimar_tokens(texto):
    if not texto:
        return 0
    return int(len(texto) / 4)

def estimar_tokens_topk(query, top_chunks, k=50):
    subset = top_chunks[:k]

    contexto = " ".join([chunk[3] for chunk in subset])

    prompt = f"""
    Responda à pergunta com base nos documentos abaixo.

    Pergunta:
    {query}

    Documentos:
    {contexto}
    """

    tokens_prompt = estimar_tokens(prompt)

    # Estimativa de resposta média (ajuste se quiser)
    tokens_resposta = 200  

    return tokens_prompt + tokens_resposta

def buscar_perguntas(limit=193):
    try:
        # --------------------------------------------------
        # 1) Leitura do CSV
        # --------------------------------------------------
        df = pd.read_csv(
            "perguntas_respostas_unificadas.xls",
            encoding="utf-8"
        )

        # --------------------------------------------------
        # 2) Seleciona as primeiras perguntas (ordem do CSV)
        # --------------------------------------------------
        perguntas = df["pergunta"].head(limit).tolist()

        return perguntas

    except Exception as e:
        print("❌ Erro ao buscar perguntas do arquivo CSV:")
        traceback.print_exc()
        return []

     
# --- BLOCO DE EXECUÇÃO PRINCIPAL ---
if __name__ == "__main__":
    perguntas = buscar_perguntas(limit=193)
    list_respostas = []
    
    for i, pergunta in enumerate(perguntas, 1):
        print(f"\n🔍 Processando pergunta {i}: \"{pergunta}\"\n")

        try:
            resultado = orquestrar_rag_duas_etapas(pergunta)


            list_respostas.append({
                "pergunta": pergunta,
                "resposta": resultado.get("resposta", ""),
                "k_utilizado": resultado.get("k_utilizado", 0),
                "num_chamadas": resultado.get("num_chamadas", 0),
                "tokens_incremental": resultado.get("tokens_estimados", 0),
                "tokens_top50": resultado.get("tokens_top50", 0),
                "economia_tokens": resultado.get("economia_tokens", 0),
                "status": resultado.get("status", "")
            })
           

            print("\n" + "="*100 + f" RESPOSTA {i} " + "="*100)
            print("Resposta:", resultado.get("resposta", ""))
            print("k_utilizado:", resultado.get("k_utilizado", 0))
            print("num_chamadas:", resultado.get("num_chamadas", 0))
            print("tokens_estimados:", resultado.get("tokens_estimados", 0))
            print("status:", resultado.get("status", ""))
            print("="*192)

            print(f"""
            📊 Comparação de custo:
            - Tokens incremental: {resultado.get("tokens_estimados", 0)}
            - Tokens Top-50: {resultado.get("tokens_top50", 0)}
            - Economia: {resultado.get("economia_tokens", 0)*100:.2f}%
            """)
                     
            
        except Exception as e:
            print(f"\n--- ERRO ao processar pergunta {i} ---")
            traceback.print_exc()
    # Criação dos DataFrames
    df_respostas = pd.DataFrame(list_respostas)
   
    # Salva resultados em arquivos CSV
    df_respostas.to_csv('resultados_incremental_sabia3_1.csv')
    
   # print("\n📋 DataFrame - Cosine")
   # print(df_cosine.head())

    print("\n📋 DataFrame - Respostas")
    print(df_respostas.head())
    print("\n✅ Todas as perguntas foram processadas.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mvcun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Carregando o modelo de embeddings...
# Modelo carregado.
#
# 🔍 Processando pergunta 1: "Quais formulários são mencionados no documento como disponíveis no site do HE -> Sistemas -> ADS Hospitalar -> Documentos -> USOST – Unidade de Saúde Ocupacional e Segurança do Trabalho, e para quais finalidades são utilizados?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: No site do HE, na seção Sistemas -> ADS Hospitalar -> Documentos -> USOST, estão disponíveis os seguintes formulários, com suas finalidades:
#
# 1. **USOST-029 - Autorização para trabalho a quente**: Utilizado em atividades que envolvem fontes de ignição (aquecimento, centelha ou chama) em áreas com presença potencial de material inflamável ou combustível, para evitar incêndios e explosões.
#
# 2. **USOST-030 - Permissão de Entrada e Trabalho em espaços confinados – PET**: Necessário para atividades em espaços confinados, garantindo que a atmosfera interna seja segura, o monitoramento contínuo das condições de oxigênio, explosividade e toxidez, além de assegurar procedimentos de emergência e resgate.
#
# 3. **USOST-039 Etiqueta bloqueio de energias perigosas**: Utilizado para garantir que equipamentos não sejam acionados acidentalmente durante manutenção, limpeza ou outras intervenções, envolvendo o bloqueio de energias elétrica, mecânica, hidráulica, pneumática, química e térmica.
#
# Estes formulários são emitidos junto com a Permissão de Trabalho de Risco (PTR) e seus anexos, conforme as necessidades específicas de cada atividade.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 1 ====================================================================================================
# Resposta: No site do HE, na seção Sistemas -> ADS Hospitalar -> Documentos -> USOST, estão disponíveis os seguintes formulários, com suas finalidades:
#
# 1. **USOST-029 - Autorização para trabalho a quente**: Utilizado em atividades que envolvem fontes de ignição (aquecimento, centelha ou chama) em áreas com presença potencial de material inflamável ou combustível, para evitar incêndios e explosões.
#
# 2. **USOST-030 - Permissão de Entrada e Trabalho em espaços confinados – PET**: Necessário para atividades em espaços confinados, garantindo que a atmosfera interna seja segura, o monitoramento contínuo das condições de oxigênio, explosividade e toxidez, além de assegurar procedimentos de emergência e resgate.
#
# 3. **USOST-039 Etiqueta bloqueio de energias perigosas**: Utilizado para garantir que equipamentos não sejam acionados acidentalmente durante manutenção, limpeza ou outras intervenções, envolvendo o bloqueio de energias elétrica, mecânica, hidráulica, pneumática, química e térmica.
#
# Estes formulários são emitidos junto com a Permissão de Trabalho de Risco (PTR) e seus anexos, conforme as necessidades específicas de cada atividade.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3641
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3641
#             - Tokens Top-50: 101735
#             - Economia: 96.42%
#
#
# 🔍 Processando pergunta 2: "De acordo com o documento, qual é a definição de Estágio Optativo para acadêmicos de Medicina ou residentes?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Estágio Optativo é uma atividade curricular obrigatória para acadêmicos de Medicina ou residentes, porém em área eletiva, ou seja, escolhida pelo próprio estudante.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 2 ====================================================================================================
# Resposta: Estágio Optativo é uma atividade curricular obrigatória para acadêmicos de Medicina ou residentes, porém em área eletiva, ou seja, escolhida pelo próprio estudante.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 5050
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 5050
#             - Tokens Top-50: 66961
#             - Economia: 92.46%
#
#
# 🔍 Processando pergunta 3: "Quais são os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL, de acordo com o documento?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL incluem:
# - Formulário de Solicitação de Estágio Optativo
# - Plano de Ensino, preenchido e assinado em conjunto com o supervisor do estágio
# - Declaração de seguro fornecida pelo colegiado da Faculdade de Medicina (FAMED), para acadêmicos da UFPEL
# - Termo de Compromisso de Estágio (3 vias), assinado pelo acadêmico e pela instituição de ensino, para estudantes de outras instituições
# - Carta de apresentação fornecida pela Instituição de Ensino, mencionando nome do estudante, situação atual de matrícula, nome da disciplina de estágio e carga horária total
# - Cópia de apólice de seguro contra acidentes pessoais, ou declaração da Instituição de Ensino atestando que o estudante está assegurado
# - Cópia de comprovante vacinal com as doses de Hepatite B e Dupla Adulto em dia
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 3 ====================================================================================================
# Resposta: Os materiais necessários para a formalização de um Estágio Optativo previamente aprovado no Hospital Escola UFPEL incluem:
# - Formulário de Solicitação de Estágio Optativo
# - Plano de Ensino, preenchido e assinado em conjunto com o supervisor do estágio
# - Declaração de seguro fornecida pelo colegiado da Faculdade de Medicina (FAMED), para acadêmicos da UFPEL
# - Termo de Compromisso de Estágio (3 vias), assinado pelo acadêmico e pela instituição de ensino, para estudantes de outras instituições
# - Carta de apresentação fornecida pela Instituição de Ensino, mencionando nome do estudante, situação atual de matrícula, nome da disciplina de estágio e carga horária total
# - Cópia de apólice de seguro contra acidentes pessoais, ou declaração da Instituição de Ensino atestando que o estudante está assegurado
# - Cópia de comprovante vacinal com as doses de Hepatite B e Dupla Adulto em dia
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 4999
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 4999
#             - Tokens Top-50: 80746
#             - Economia: 93.81%
#
#
# 🔍 Processando pergunta 4: "Quais são os materiais necessários para o preenchimento do Sistema ADS Ensino para o cadastro de estágios curriculares obrigatórios, incluindo a impressão dos crachás de identificação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para o preenchimento do Sistema ADS Ensino e cadastro de estágios curriculares obrigatórios, os materiais necessários são:
#
# - Computador com Internet;
# - Sistema ADS Ensino (acesso via site do HE UFPEL);
# - Formulário "Solicitação para Realizar Projeto de Ensino/Extensão no Hospital Escola e Outras Unidades";
# - Documentos para formalização do estágio (Termo de Compromisso de Estágio, Carta de apresentação, cópia da apólice de seguro contra acidentes pessoais ou declaração da Instituição de Ensino, e cópia de comprovante vacinal);
# - Impressora colorida;
# - Papel A4;
# - Plástico Polaseal para plastificação do crachá.
#
# As etapas incluem o preenchimento e conferência do cadastro de estudante, o cadastro da "Vaga Curricular" e da "Atividade Curricular", a emissão e impressão dos crachás de identificação que devem ser recortados e plastificados, e a entrega dos crachás na portaria de entrada dos funcionários ou no Setor de Ensino.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 4 ====================================================================================================
# Resposta: Para o preenchimento do Sistema ADS Ensino e cadastro de estágios curriculares obrigatórios, os materiais necessários são:
#
# - Computador com Internet;
# - Sistema ADS Ensino (acesso via site do HE UFPEL);
# - Formulário "Solicitação para Realizar Projeto de Ensino/Extensão no Hospital Escola e Outras Unidades";
# - Documentos para formalização do estágio (Termo de Compromisso de Estágio, Carta de apresentação, cópia da apólice de seguro contra acidentes pessoais ou declaração da Instituição de Ensino, e cópia de comprovante vacinal);
# - Impressora colorida;
# - Papel A4;
# - Plástico Polaseal para plastificação do crachá.
#
# As etapas incluem o preenchimento e conferência do cadastro de estudante, o cadastro da "Vaga Curricular" e da "Atividade Curricular", a emissão e impressão dos crachás de identificação que devem ser recortados e plastificados, e a entrega dos crachás na portaria de entrada dos funcionários ou no Setor de Ensino.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 6557
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6557
#             - Tokens Top-50: 60405
#             - Economia: 89.14%
#
#
# 🔍 Processando pergunta 5: "Quais são os materiais necessários para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação, os materiais necessários são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Impressora Ink Jet ou Laser colorida
# - Papel A4
# - Plástico Polaseal para plastificação do crachá
#
# Além disso, no processo de cadastro e emissão de crachás, é necessário utilizar e-mails para comunicação, bem como salvar os arquivos gerados em formato PDF em um PEN DRIVE para impressão.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 5 ====================================================================================================
# Resposta: Para o preenchimento do Sistema ADS Ensino para cadastro dos estágios optativos e impressão dos crachás de identificação, os materiais necessários são:
#
# - Computador com Internet
# - Sistema ADS Ensino (site do HE UFPEL)
# - Impressora Ink Jet ou Laser colorida
# - Papel A4
# - Plástico Polaseal para plastificação do crachá
#
# Além disso, no processo de cadastro e emissão de crachás, é necessário utilizar e-mails para comunicação, bem como salvar os arquivos gerados em formato PDF em um PEN DRIVE para impressão.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 6493
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6493
#             - Tokens Top-50: 61952
#             - Economia: 89.52%
#
#
# 🔍 Processando pergunta 6: "De acordo com a Resolução CNS nº 466/2012, item II.21, como é definido o termo 'ressarcimento' no contexto da compensação material em pesquisas?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A Resolução CNS n° 466/2012, item II.21, define ressarcimento como a "compensação material, exclusivamente de despesas do participante e seus acompanhantes, quando necessário, tais como transporte e alimentação". O TCLE deve explicitar a garantia de ressarcimento das despesas incorridas pelo participante da pesquisa e decorrentes dela, sem qualquer custo para o participante.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 6 ====================================================================================================
# Resposta: A Resolução CNS n° 466/2012, item II.21, define ressarcimento como a "compensação material, exclusivamente de despesas do participante e seus acompanhantes, quando necessário, tais como transporte e alimentação". O TCLE deve explicitar a garantia de ressarcimento das despesas incorridas pelo participante da pesquisa e decorrentes dela, sem qualquer custo para o participante.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 4235
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 4235
#             - Tokens Top-50: 55673
#             - Economia: 92.39%
#
#
# 🔍 Processando pergunta 7: "Quais formulários são utilizados na rotina de monitorias remotas descrita no documento, e para que propósito cada um serve?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Formulário CPC – 003 Anuência para Monitoria Remota: Documenta a anuência da Chefia do Setor de Pesquisa e Inovações Tecnológicas em Saúde para a realização de monitorias remotas, sendo arquivado nos documentos do CPC.
#
# Formulário CPC – 004 Ciência para Monitoria Remota: Deve ser preenchido pelos investigadores e sub-investigadores para documentar sua ciência e respaldar a execução das monitorias remotas.
#
# Formulário CPC – 005 Acordo de Confidencialidade: Encaminhado pelo monitor 24 horas antes da monitoria remota, compromete o monitor a utilizar a documentação-fonte de forma adequada, destruir cópias após a verificação e não fazer gravações ou cópias dos documentos-fonte.
#
# Relatório da Monitoria: No final de cada monitoria remota, o monitor deve especificar o método utilizado, os documentos verificados e confirmar o uso adequado e a inexistência de arquivos ou gravações dos documentos-fonte.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 7 ====================================================================================================
# Resposta: Formulário CPC – 003 Anuência para Monitoria Remota: Documenta a anuência da Chefia do Setor de Pesquisa e Inovações Tecnológicas em Saúde para a realização de monitorias remotas, sendo arquivado nos documentos do CPC.
#
# Formulário CPC – 004 Ciência para Monitoria Remota: Deve ser preenchido pelos investigadores e sub-investigadores para documentar sua ciência e respaldar a execução das monitorias remotas.
#
# Formulário CPC – 005 Acordo de Confidencialidade: Encaminhado pelo monitor 24 horas antes da monitoria remota, compromete o monitor a utilizar a documentação-fonte de forma adequada, destruir cópias após a verificação e não fazer gravações ou cópias dos documentos-fonte.
#
# Relatório da Monitoria: No final de cada monitoria remota, o monitor deve especificar o método utilizado, os documentos verificados e confirmar o uso adequado e a inexistência de arquivos ou gravações dos documentos-fonte.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 5695
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 5695
#             - Tokens Top-50: 51499
#             - Economia: 88.94%
#
#
# 🔍 Processando pergunta 8: "De acordo com o documento, qual a responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna é:
#
# Elaborar o projeto básico de capacitação conforme a capacitação validada no Plano de Desenvolvimento de Competências (PDC). As demandas de capacitações extemporâneas devem ser justificadas e encaminhadas à Unidade de Desenvolvimento de Pessoas (UDP). Preencher o Formulário SEI_Projeto Básico de Capacitação de acordo com as orientações do PDC vigente, assinar o projeto básico e providenciar as assinaturas necessárias, incluindo assistente, chefia da área demandante e demais responsáveis conforme definido no PDC. Emitir despacho detalhando os papéis e perfis para a execução da capacitação, conforme o art. 3o da Portaria-SEI no 2931/2022/DGP-EBSERH, incluindo nome, cargo e justificativa da qualificação do colaborador indicado. Enviar o projeto via sistema SEI com 60 dias de antecedência à realização da ação para a unidade UDP e aguardar a elaboração da nota técnica de aprovação ou despacho preliminar.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 8 ====================================================================================================
# Resposta: A responsabilidade do coordenador da ação de instrutoria interna referente à elaboração do projeto básico de capacitação para instrutoria interna é:
#
# Elaborar o projeto básico de capacitação conforme a capacitação validada no Plano de Desenvolvimento de Competências (PDC). As demandas de capacitações extemporâneas devem ser justificadas e encaminhadas à Unidade de Desenvolvimento de Pessoas (UDP). Preencher o Formulário SEI_Projeto Básico de Capacitação de acordo com as orientações do PDC vigente, assinar o projeto básico e providenciar as assinaturas necessárias, incluindo assistente, chefia da área demandante e demais responsáveis conforme definido no PDC. Emitir despacho detalhando os papéis e perfis para a execução da capacitação, conforme o art. 3o da Portaria-SEI no 2931/2022/DGP-EBSERH, incluindo nome, cargo e justificativa da qualificação do colaborador indicado. Enviar o projeto via sistema SEI com 60 dias de antecedência à realização da ação para a unidade UDP e aguardar a elaboração da nota técnica de aprovação ou despacho preliminar.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 4537
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 4537
#             - Tokens Top-50: 81644
#             - Economia: 94.44%
#
#
# 🔍 Processando pergunta 9: "Qual o prazo que o colaborador apto para a instrutoria interna tem, após o recebimento do despacho de indicação pela UDP, para manifestar confirmação ou indisponibilidade,  e o que precisa ser feito?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: O colaborador apto para a instrutoria interna tem um prazo de 7 dias após o recebimento do despacho de indicação pela Unidade de Desenvolvimento de Pessoas (UDP) para manifestar confirmação ou indisponibilidade. Durante esse período, ele deve preencher o Termo de Ciência da Atividade de Instrutoria Interna no Sistema Eletrônico de Informações (SEI), com a assinatura do instrutor e de sua chefia imediata, ou enviar um despacho informando a indisponibilidade para atuar na ação de capacitação.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 9 ====================================================================================================
# Resposta: O colaborador apto para a instrutoria interna tem um prazo de 7 dias após o recebimento do despacho de indicação pela Unidade de Desenvolvimento de Pessoas (UDP) para manifestar confirmação ou indisponibilidade. Durante esse período, ele deve preencher o Termo de Ciência da Atividade de Instrutoria Interna no Sistema Eletrônico de Informações (SEI), com a assinatura do instrutor e de sua chefia imediata, ou enviar um despacho informando a indisponibilidade para atuar na ação de capacitação.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 8796
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 8796
#             - Tokens Top-50: 86366
#             - Economia: 89.82%
#
#
# 🔍 Processando pergunta 10: "Quais são os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH)?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH) são:
#
# 1. Portaria- SEI no 2931/2022/DGP-EBSERH, que regulamenta a instrutoria interna no âmbito da Rede Ebserh.
# 2. Norma - SEI no 5/2022/DGP-EBSERH, que dispõe sobre as ações de capacitação no âmbito da EBSERH.
#
# Estes documentos fornecem diretrizes sobre a definição dos papéis nas ações de capacitação e regulamentam a instrutoria interna, incluindo a elaboração de projetos básicos de capacitação e a designação de responsáveis pela execução das ações de instrutoria.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 10 ====================================================================================================
# Resposta: Os documentos normativos citados que regem as ações de capacitação e a instrutoria interna na Empresa Brasileira de Serviços Hospitalares (EBSERH) são:
#
# 1. Portaria- SEI no 2931/2022/DGP-EBSERH, que regulamenta a instrutoria interna no âmbito da Rede Ebserh.
# 2. Norma - SEI no 5/2022/DGP-EBSERH, que dispõe sobre as ações de capacitação no âmbito da EBSERH.
#
# Estes documentos fornecem diretrizes sobre a definição dos papéis nas ações de capacitação e regulamentam a instrutoria interna, incluindo a elaboração de projetos básicos de capacitação e a designação de responsáveis pela execução das ações de instrutoria.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 4501
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 4501
#             - Tokens Top-50: 66971
#             - Economia: 93.28%
#
#
# 🔍 Processando pergunta 11: "De acordo com o documento, qual o procedimento a ser adotado pelo NAA quando a escala de trabalho é recebida após o dia 15 do mês antecedente à escala de referência?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Quando a escala de trabalho é recebida após o dia 15 do mês antecedente à escala de referência, a escala será arquivada pelo NAA e o cadastramento dos horários de trabalho dos empregados no sistema SIGP/MENTORH ficará sob responsabilidade do gestor. Além disso, a escala será incluída no bloco interno do SEI em pasta previamente criada com o mês correspondente e nomeada com a informação "Fora do Prazo".
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 11 ====================================================================================================
# Resposta: Quando a escala de trabalho é recebida após o dia 15 do mês antecedente à escala de referência, a escala será arquivada pelo NAA e o cadastramento dos horários de trabalho dos empregados no sistema SIGP/MENTORH ficará sob responsabilidade do gestor. Além disso, a escala será incluída no bloco interno do SEI em pasta previamente criada com o mês correspondente e nomeada com a informação "Fora do Prazo".
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 8347
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 8347
#             - Tokens Top-50: 71390
#             - Economia: 88.31%
#
#
# 🔍 Processando pergunta 12: "Descreva o procedimento para o tratamento de inconsistências encontradas nas escalas de trabalho, especificando as ações das chefias, os formulários utilizados e os departamentos envolvidos no processo de correção."
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para tratar inconsistências nas escalas de trabalho, a chefia imediata deve ser notificada via processo SEI sigiloso sobre a data e horário do acolhimento do colaborador pelo enfermeiro de saúde mental. O enfermeiro de saúde mental e a médica do trabalho discutirão o caso para determinar a necessidade de avaliação ocupacional. Se necessário, a médica do trabalho agendará uma consulta com o colaborador para avaliar a necessidade de atestado médico ou retorno ao trabalho. As escalas com inconsistências serão devolvidas ao gestor para correções, utilizando o Formulário de Alteração de Horário Individual no SEI para ajustar os horários dos empregados. A USOST, Unidade de Administração de Pessoal (UAP) e Divisão de Gestão de Pessoas (DIVGP) estão envolvidas no processo de correção, garantindo que as escalas estejam de acordo com a legislação vigente e as normas estabelecidas. A comunicação entre as partes é feita majoritariamente via e-mail institucional e processos SEI sigilosos, com registros relevantes também feitos em prontuários para acompanhamento adequado.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 12 ====================================================================================================
# Resposta: Para tratar inconsistências nas escalas de trabalho, a chefia imediata deve ser notificada via processo SEI sigiloso sobre a data e horário do acolhimento do colaborador pelo enfermeiro de saúde mental. O enfermeiro de saúde mental e a médica do trabalho discutirão o caso para determinar a necessidade de avaliação ocupacional. Se necessário, a médica do trabalho agendará uma consulta com o colaborador para avaliar a necessidade de atestado médico ou retorno ao trabalho. As escalas com inconsistências serão devolvidas ao gestor para correções, utilizando o Formulário de Alteração de Horário Individual no SEI para ajustar os horários dos empregados. A USOST, Unidade de Administração de Pessoal (UAP) e Divisão de Gestão de Pessoas (DIVGP) estão envolvidas no processo de correção, garantindo que as escalas estejam de acordo com a legislação vigente e as normas estabelecidas. A comunicação entre as partes é feita majoritariamente via e-mail institucional e processos SEI sigilosos, com registros relevantes também feitos em prontuários para acompanhamento adequado.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 13641
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 13641
#             - Tokens Top-50: 51886
#             - Economia: 73.71%
#
#
# 🔍 Processando pergunta 13: "Quais são os passos para inserir as escalas de trabalho nas pastas, após a criação das pastas anuais e mensais, de acordo com as instruções fornecidas?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Após a criação das pastas anuais e mensais, os passos para inserir as escalas de trabalho nas pastas são:
#
# 1. Baixar a escala de trabalho contida no processo SEI, que deve estar em formato PDF.
# 2. Arquivar a escala no computador, seguindo o caminho: Computador > NAA > Escalas Mensais > Ano Correspondente > Pasta da Unidade Correspondente.
# 3. Nomear a escala salva seguindo o padrão: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022.
#
# Se a escala for recebida fora do prazo, o NAA deverá:
#
# 1. Informar na planilha de controle a informação "Fora do Prazo".
# 2. Incluir a escala no bloco interno do SEI, na pasta previamente criada com o mês correspondente, e nomeá-la através do ícone de anotações com a informação da unidade correspondente e "Fora do Prazo".
#
# Esses procedimentos garantem que as escalas de trabalho sejam devidamente arquivadas e organizadas para futuras consultas e controle.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 13 ====================================================================================================
# Resposta: Após a criação das pastas anuais e mensais, os passos para inserir as escalas de trabalho nas pastas são:
#
# 1. Baixar a escala de trabalho contida no processo SEI, que deve estar em formato PDF.
# 2. Arquivar a escala no computador, seguindo o caminho: Computador > NAA > Escalas Mensais > Ano Correspondente > Pasta da Unidade Correspondente.
# 3. Nomear a escala salva seguindo o padrão: Nome da unidade_Profissional_Mês_Ano. Exemplo: CLÍNICA_MÉDICA_ENF_FEV_2022.
#
# Se a escala for recebida fora do prazo, o NAA deverá:
#
# 1. Informar na planilha de controle a informação "Fora do Prazo".
# 2. Incluir a escala no bloco interno do SEI, na pasta previamente criada com o mês correspondente, e nomeá-la através do ícone de anotações com a informação da unidade correspondente e "Fora do Prazo".
#
# Esses procedimentos garantem que as escalas de trabalho sejam devidamente arquivadas e organizadas para futuras consultas e controle.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 8472
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 8472
#             - Tokens Top-50: 60866
#             - Economia: 86.08%
#
#
# 🔍 Processando pergunta 14: "Qual o procedimento descrito no documento para anexar a Declaração de Dispensa no sistema SEI UFPel, após o preenchimento do formulário PROGEP: Requerimento de Benefícios?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Após preencher o formulário PROGEP: Requerimento de Benefícios, o servidor deve selecionar a opção "Incluir Documento" no sistema SEI UFPel, escolher o Tipo de Documento "Externo", preencher os campos como Tipo de Documento "Declaração", Data do Documento, Número/Nome na Árvore como "Justiça Eleitoral", Formato, Nível de Acesso e Hipótese Legal, e anexar o arquivo da Declaração de Dispensa fornecida pela Justiça Eleitoral. Depois disso, o servidor deve informar o número do processo à chefia da Unidade para assinatura e enviar o processo à Seção de Apoio Administrativo – SAAD/PROGEP. Após enviar ao SAAD, o servidor deve acompanhar o processo para conferir se a folga foi autorizada e lançada pela PROGEP. É importante que a folga seja autorizada pela chefia e o processo enviado à SAAD antes da data prevista para o gozo da folga.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 14 ====================================================================================================
# Resposta: Após preencher o formulário PROGEP: Requerimento de Benefícios, o servidor deve selecionar a opção "Incluir Documento" no sistema SEI UFPel, escolher o Tipo de Documento "Externo", preencher os campos como Tipo de Documento "Declaração", Data do Documento, Número/Nome na Árvore como "Justiça Eleitoral", Formato, Nível de Acesso e Hipótese Legal, e anexar o arquivo da Declaração de Dispensa fornecida pela Justiça Eleitoral. Depois disso, o servidor deve informar o número do processo à chefia da Unidade para assinatura e enviar o processo à Seção de Apoio Administrativo – SAAD/PROGEP. Após enviar ao SAAD, o servidor deve acompanhar o processo para conferir se a folga foi autorizada e lançada pela PROGEP. É importante que a folga seja autorizada pela chefia e o processo enviado à SAAD antes da data prevista para o gozo da folga.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 6970
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6970
#             - Tokens Top-50: 91799
#             - Economia: 92.41%
#
#
# 🔍 Processando pergunta 15: "Quais são os passos necessários para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, incluindo as ações para alteração de lotação e vacância?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, siga os passos abaixo:
#
# 1. Acesse o sistema SIP e clique em "Usuários" + "Novo".
# 2. Preencha os dados solicitados:
#    - Órgão: HE-UFPEL
#    - Sigla: usuário do servidor (nome.sobrenome)
#    - Nome: nome completo do servidor
#    - ID Origem: deixe em branco
# 3. Salve o cadastro do usuário.
#
# Para o cadastro de permissões:
#
# 1. Clique em "Permissões" + "Nova".
# 2. Preencha as informações necessárias:
#    - Órgão do Sistema: SEDE
#    - Sistema: SEI
#    - Órgão da Unidade: HE-UFPEL
#    - Órgão do Usuário: HE-UFPEL
#    - Perfil: Básica
#    - Unidade: cadastre a unidade do servidor
#    - Usuário: cadastre a sigla do servidor (nome.sobrenome)
# 3. Salve a nova permissão.
#
# Para alteração de lotação:
#
# 1. Inclua a data final na permissão vigente.
# 2. Cadastre uma nova permissão para o usuário com a nova unidade de lotação.
#
# Para vacância:
#
# 1. Inclua a data final na permissão vigente para desativar o acesso do servidor.
#
# Referências para o sistema SIP podem ser encontradas no link: https://sei.ebserh.gov.br/sip/login.php?sigla_orgao_sistema=SEDE&sigla_sistema=SIP&infra_url=L3NpcC8=.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 15 ====================================================================================================
# Resposta: Para cadastrar as permissões de um servidor RJU no sistema SIP para acesso ao SEI EBSERH, siga os passos abaixo:
#
# 1. Acesse o sistema SIP e clique em "Usuários" + "Novo".
# 2. Preencha os dados solicitados:
#    - Órgão: HE-UFPEL
#    - Sigla: usuário do servidor (nome.sobrenome)
#    - Nome: nome completo do servidor
#    - ID Origem: deixe em branco
# 3. Salve o cadastro do usuário.
#
# Para o cadastro de permissões:
#
# 1. Clique em "Permissões" + "Nova".
# 2. Preencha as informações necessárias:
#    - Órgão do Sistema: SEDE
#    - Sistema: SEI
#    - Órgão da Unidade: HE-UFPEL
#    - Órgão do Usuário: HE-UFPEL
#    - Perfil: Básica
#    - Unidade: cadastre a unidade do servidor
#    - Usuário: cadastre a sigla do servidor (nome.sobrenome)
# 3. Salve a nova permissão.
#
# Para alteração de lotação:
#
# 1. Inclua a data final na permissão vigente.
# 2. Cadastre uma nova permissão para o usuário com a nova unidade de lotação.
#
# Para vacância:
#
# 1. Inclua a data final na permissão vigente para desativar o acesso do servidor.
#
# Referências para o sistema SIP podem ser encontradas no link: https://sei.ebserh.gov.br/sip/login.php?sigla_orgao_sistema=SEDE&sigla_sistema=SIP&infra_url=L3NpcC8=.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 9168
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 9168
#             - Tokens Top-50: 67749
#             - Economia: 86.47%
#
#
# 🔍 Processando pergunta 16: "Qual o prazo de entrega do formulário DIVGP – DASF – 001 Remanejamento Interno RJU ao Departamento de Apoio ao Servidor Federal (DivGP), contado a partir da data da efetiva mudança de lotação?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: O prazo de entrega do formulário DIVGP – DASF – 001 Remanejamento Interno RJU ao Departamento de Apoio ao Servidor Federal (DivGP) é de 15 dias de antecedência da efetiva mudança de lotação.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 16 ====================================================================================================
# Resposta: O prazo de entrega do formulário DIVGP – DASF – 001 Remanejamento Interno RJU ao Departamento de Apoio ao Servidor Federal (DivGP) é de 15 dias de antecedência da efetiva mudança de lotação.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3889
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3889
#             - Tokens Top-50: 51753
#             - Economia: 92.49%
#
#
# 🔍 Processando pergunta 17: "Qual o tempo médio de duração da higienização simples das mãos com água e sabonete, e qual o tempo médio da fricção antisséptica das mãos com preparações alcoólicas?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A higienização simples das mãos com água e sabonete dura em média 40-60 segundos. Já a fricção antisséptica das mãos com preparações alcoólicas dura em média 30 segundos.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 17 ====================================================================================================
# Resposta: A higienização simples das mãos com água e sabonete dura em média 40-60 segundos. Já a fricção antisséptica das mãos com preparações alcoólicas dura em média 30 segundos.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 2741
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 2741
#             - Tokens Top-50: 47893
#             - Economia: 94.28%
#
#
# 🔍 Processando pergunta 18: "Qual o tempo mínimo de fricção recomendado para a antissepsia cirúrgica das mãos na primeira cirurgia e nas cirurgias subsequentes, respectivamente, de acordo com o documento?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: O tempo mínimo de fricção recomendado para a antissepsia cirúrgica das mãos na primeira cirurgia é de 03 a 05 minutos e, para as cirurgias subsequentes, é de 02 a 03 minutos.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 18 ====================================================================================================
# Resposta: O tempo mínimo de fricção recomendado para a antissepsia cirúrgica das mãos na primeira cirurgia é de 03 a 05 minutos e, para as cirurgias subsequentes, é de 02 a 03 minutos.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3399
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3399
#             - Tokens Top-50: 42462
#             - Economia: 92.00%
#
#
# 🔍 Processando pergunta 19: "Quais são as informações contidas na nota registrada no AGHU quando se trata de precaução de contato por bactéria multirresistente, de acordo com o documento?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: A enfermeira do SCIRAS registra no AGHU uma nota com as seguintes informações: nome do microrganismo, sítio/material coletado, data da coleta e a observação "REINTERNAÇÃO ATÉ XX/XX/XXXX (1 ano após coleta) EM PRECAUÇÃO DE CONTATO".
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 19 ====================================================================================================
# Resposta: A enfermeira do SCIRAS registra no AGHU uma nota com as seguintes informações: nome do microrganismo, sítio/material coletado, data da coleta e a observação "REINTERNAÇÃO ATÉ XX/XX/XXXX (1 ano após coleta) EM PRECAUÇÃO DE CONTATO".
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 6227
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6227
#             - Tokens Top-50: 44565
#             - Economia: 86.03%
#
#
# 🔍 Processando pergunta 20: "De acordo com o documento, qual o tempo de duração recomendado para a higiene das mãos com água e sabonete líquido e com preparação alcoólica, respectivamente?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: De acordo com os documentos fornecidos, o tempo de duração recomendado para a higiene das mãos com água e sabonete líquido é de 40 a 60 segundos. Para a higienização com preparação alcoólica, o tempo recomendado é de 20 a 30 segundos.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 20 ====================================================================================================
# Resposta: De acordo com os documentos fornecidos, o tempo de duração recomendado para a higiene das mãos com água e sabonete líquido é de 40 a 60 segundos. Para a higienização com preparação alcoólica, o tempo recomendado é de 20 a 30 segundos.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 2408
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 2408
#             - Tokens Top-50: 38257
#             - Economia: 93.71%
#
#
# 🔍 Processando pergunta 21: "Quais são os materiais necessários para o processo de recebimento, conferência e armazenamento de medicamentos do Patrocinador do Estudo, conforme descrito no documento?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Armário exclusivo para o armazenamento de medicamentos, computador com internet, geladeira (quando necessário), pasta de controle de lotes recebidos, termômetro, blocos de gelo, caixa rígida térmica, datalogger de temperatura, termo-higrômetro e refrigeradores científicos.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 21 ====================================================================================================
# ...
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3325
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3325
#             - Tokens Top-50: 61970
#             - Economia: 94.63%
#
#
# 🔍 Processando pergunta 187: "Como faço para solicitar uma folga eleitoral?
#
# "
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para solicitar uma folga eleitoral, o servidor deve fazer login no SEI UFPel, iniciar um processo do tipo "Pessoal: Dispensa por serviço prestado à Justiça Eleitoral (TRE)", preencher e assinar o formulário "PROGEP: Requerimento de Benefícios" selecionando "Ausência serviço prestado Justiça Eleitoral" e informando a data da folga solicitada. Em seguida, deve anexar a "Declaração de Dispensa" fornecida pela Justiça Eleitoral, garantindo que o documento seja incluído como "Externo" com o tipo "Declaração", e o nível de acesso seja "restrito". Após preenchimento e assinatura, o servidor deve informar o número do processo à chefia para assinatura e enviar o processo ao SAAD/PROGEP antes da data prevista para o gozo da folga.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 187 ====================================================================================================
# Resposta: Para solicitar uma folga eleitoral, o servidor deve fazer login no SEI UFPel, iniciar um processo do tipo "Pessoal: Dispensa por serviço prestado à Justiça Eleitoral (TRE)", preencher e assinar o formulário "PROGEP: Requerimento de Benefícios" selecionando "Ausência serviço prestado Justiça Eleitoral" e informando a data da folga solicitada. Em seguida, deve anexar a "Declaração de Dispensa" fornecida pela Justiça Eleitoral, garantindo que o documento seja incluído como "Externo" com o tipo "Declaração", e o nível de acesso seja "restrito". Após preenchimento e assinatura, o servidor deve informar o número do processo à chefia para assinatura e enviar o processo ao SAAD/PROGEP antes da data prevista para o gozo da folga.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3688
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3688
#             - Tokens Top-50: 87863
#             - Economia: 95.80%
#
#
# 🔍 Processando pergunta 188: "Como formalizar a troca de unidade ( lotação) por servidores no Hospital Escola?
#
# "
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para formalizar a troca de unidade (lotação) por servidores no Hospital Escola, deve-se seguir os procedimentos descritos no Documento 1. A chefia de origem deve imprimir e preencher o formulário "DIVGP – DASF – 001 Remanejamento Interno RJU" disponível no sistema ADS Hospitalar, na aba documentos, pasta DIVGP/DASF. Este formulário deve conter os dados solicitados, incluindo a manifestação do servidor, da chefia imediata e da chefia de destino, informando a data do remanejamento e os horários que serão realizados pelo servidor. Após o preenchimento e assinatura dos envolvidos, o formulário deve ser entregue no Departamento de Apoio ao Servidor Federal (DivGP) com 15 dias de antecedência da efetiva mudança de lotação. No momento do recebimento, o Departamento de Apoio ao Servidor Federal deverá realizar as atualizações necessárias em seus controles internos.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 188 ====================================================================================================
# Resposta: Para formalizar a troca de unidade (lotação) por servidores no Hospital Escola, deve-se seguir os procedimentos descritos no Documento 1. A chefia de origem deve imprimir e preencher o formulário "DIVGP – DASF – 001 Remanejamento Interno RJU" disponível no sistema ADS Hospitalar, na aba documentos, pasta DIVGP/DASF. Este formulário deve conter os dados solicitados, incluindo a manifestação do servidor, da chefia imediata e da chefia de destino, informando a data do remanejamento e os horários que serão realizados pelo servidor. Após o preenchimento e assinatura dos envolvidos, o formulário deve ser entregue no Departamento de Apoio ao Servidor Federal (DivGP) com 15 dias de antecedência da efetiva mudança de lotação. No momento do recebimento, o Departamento de Apoio ao Servidor Federal deverá realizar as atualizações necessárias em seus controles internos.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3986
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3986
#             - Tokens Top-50: 70337
#             - Economia: 94.33%
#
#
# 🔍 Processando pergunta 189: "quem pode fazer as inspeções de OLA?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: As inspeções de OLA podem ser feitas exclusivamente por profissionais da USOST (Unidade de Segurança e Saúde Ocupacional). Chefias dos locais ou serviços avaliados podem facultativamente acompanhar a realização das inspeções e, se necessário, designar outro profissional para o acompanhamento.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 189 ====================================================================================================
# Resposta: As inspeções de OLA podem ser feitas exclusivamente por profissionais da USOST (Unidade de Segurança e Saúde Ocupacional). Chefias dos locais ou serviços avaliados podem facultativamente acompanhar a realização das inspeções e, se necessário, designar outro profissional para o acompanhamento.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3896
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3896
#             - Tokens Top-50: 41570
#             - Economia: 90.63%
#
#
# 🔍 Processando pergunta 190: "o que fazer em relação da rotulagem dos produtos quimicos?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Manter a rotulagem original dos produtos químicos é essencial para a segurança nos serviços de saúde. Além disso, todas as embalagens de produtos químicos fracionados devem ser rotuladas com o nome do produto, composição química, concentração, data de envase e validade, e nome do responsável pela manipulação ou fracionamento. É vedado reutilizar embalagens de produtos químicos, a menos que seja permitido pelo fabricante. As empresas contratadas devem seguir as instruções das fichas de Informação de Segurança de Produtos Químicos (FISPQ) e manter atualizada a capacitação dos funcionários envolvidos com produtos químicos. Em caso de qualquer anomalia, comunicar imediatamente à Unidade de Saúde Ocupacional e Segurança do Trabalho.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 190 ====================================================================================================
# Resposta: Manter a rotulagem original dos produtos químicos é essencial para a segurança nos serviços de saúde. Além disso, todas as embalagens de produtos químicos fracionados devem ser rotuladas com o nome do produto, composição química, concentração, data de envase e validade, e nome do responsável pela manipulação ou fracionamento. É vedado reutilizar embalagens de produtos químicos, a menos que seja permitido pelo fabricante. As empresas contratadas devem seguir as instruções das fichas de Informação de Segurança de Produtos Químicos (FISPQ) e manter atualizada a capacitação dos funcionários envolvidos com produtos químicos. Em caso de qualquer anomalia, comunicar imediatamente à Unidade de Saúde Ocupacional e Segurança do Trabalho.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 6440
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 6440
#             - Tokens Top-50: 56478
#             - Economia: 88.60%
#
#
# 🔍 Processando pergunta 191: "o que fazer se eu me acidentar durante o uso de produtos quimicos?"
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Se você se acidentar durante o uso de produtos químicos, siga as instruções específicas contidas nas Fichas de Informação de Segurança de Produtos Químicos (FISPQ) para o produto em questão. Além disso, consulte um médico imediatamente ou assim que possível. Se ocorrer uma contaminação ambiental, utilize o kit de segurança para derramamento de produtos químicos disponível no local, que inclui itens como óculos de segurança, avental impermeável, máscara respiratória, luvas nitrílicas, sacos de 100L, serragem ou mantas absorventes, vassoura e pá. Após o uso, descarte imediatamente os itens não reutilizáveis e higienize os reutilizáveis.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 191 ====================================================================================================
# Resposta: Se você se acidentar durante o uso de produtos químicos, siga as instruções específicas contidas nas Fichas de Informação de Segurança de Produtos Químicos (FISPQ) para o produto em questão. Além disso, consulte um médico imediatamente ou assim que possível. Se ocorrer uma contaminação ambiental, utilize o kit de segurança para derramamento de produtos químicos disponível no local, que inclui itens como óculos de segurança, avental impermeável, máscara respiratória, luvas nitrílicas, sacos de 100L, serragem ou mantas absorventes, vassoura e pá. Após o uso, descarte imediatamente os itens não reutilizáveis e higienize os reutilizáveis.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 3570
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 3570
#             - Tokens Top-50: 62778
#             - Economia: 94.31%
#
#
# 🔍 Processando pergunta 192: "Estou me sentindo ansioso e sobre carregado. como faço para pedir ajuda? "
#
# Encontrados 740 registros no banco de dados.
# Recuperação inicial concluída. 100 chunks selecionados.
# 🔎 Total de chunks disponíveis: 100
#
# 🚀 Iniciando RAG Incremental...
#
# 🔎 Testando com top-5 chunks
# Resposta: Para pedir ajuda quando estiver se sentindo ansioso e sobrecarregado, você deve entrar em contato com o enfermeiro de saúde mental através do e-mail sm.usost.he-ufpel@ebserh.gov.br ou pelo Ramal 5166. O enfermeiro agendará uma escuta qualificada, onde você poderá compartilhar suas necessidades emocionais. Após essa avaliação, podem ser feitos encaminhamentos para outros profissionais da equipe de saúde mental, como psiquiatras, psicólogos e médicos do trabalho, conforme necessário. Seu caso será acompanhado e discutido para garantir o devido cuidado e suporte. A chefia imediata será informada de maneira sigilosa sobre o acolhimento, mas sua identidade poderá ser preservada caso opte pelo sigilo.
# ✅ Resposta encontrada com top-5
#
# ==================================================================================================== RESPOSTA 192 ====================================================================================================
# Resposta: Para pedir ajuda quando estiver se sentindo ansioso e sobrecarregado, você deve entrar em contato com o enfermeiro de saúde mental através do e-mail sm.usost.he-ufpel@ebserh.gov.br ou pelo Ramal 5166. O enfermeiro agendará uma escuta qualificada, onde você poderá compartilhar suas necessidades emocionais. Após essa avaliação, podem ser feitos encaminhamentos para outros profissionais da equipe de saúde mental, como psiquiatras, psicólogos e médicos do trabalho, conforme necessário. Seu caso será acompanhado e discutido para garantir o devido cuidado e suporte. A chefia imediata será informada de maneira sigilosa sobre o acolhimento, mas sua identidade poderá ser preservada caso opte pelo sigilo.
# k_utilizado: 5
# num_chamadas: 1
# tokens_estimados: 17726
# status: SUCESSO
# ================================================================================================================================================================================================
#
#             📊 Comparação de custo:
#             - Tokens incremental: 17726
#             - Tokens Top-50: 138679
#             - Economia: 87.22%
#
#
# 📋 DataFrame - Respostas
#                                             pergunta  \
# 0  Quais formulários são mencionados no documento...
# 1  De acordo com o documento, qual é a definição ...
# 2  Quais são os materiais necessários para a form...
# 3  Quais são os materiais necessários para o pree...
# 4  Quais são os materiais necessários para o pree...
#
#                                             resposta  k_utilizado  \
# 0  No site do HE, na seção Sistemas -> ADS Hospit...            5
# 1  Estágio Optativo é uma atividade curricular ob...            5
# 2  Os materiais necessários para a formalização d...            5
# 3  Para o preenchimento do Sistema ADS Ensino e c...            5
# 4  Para o preenchimento do Sistema ADS Ensino par...            5
#
#    num_chamadas  tokens_incremental  tokens_top50  economia_tokens   status
# 0             1                3641        101735         0.964211  SUCESSO
# 1             1                5050         66961         0.924583  SUCESSO
# 2             1                4999         80746         0.938090  SUCESSO
# 3             1                6557         60405         0.891449  SUCESSO
# 4             1                6493         61952         0.895193  SUCESSO
#
# ✅ Todas as perguntas foram processadas.

# %%
# Avaliação respostas geradas com BertScore
import pandas as pd
from bert_score import score

# --- BLOCO DE EXECUÇÃO PRINCIPAL ---
if __name__ == "__main__":
    
    # --------------------------------------------------------------
    # 1) Carrega as respostas de referência (gabarito) do CSV
    # --------------------------------------------------------------
    df_gabarito = pd.read_csv("perguntas_respostas_unificadas.xls")

    # Converte tudo para string e remove NaN
    df_gabarito["resposta"] = df_gabarito["resposta"].fillna("").astype(str)

    respostas_referencia = df_gabarito["resposta"].tolist()
    

    # --------------------------------------------------------------
    # 2) Carrega as respostas geradas pelo re-ranker
    # --------------------------------------------------------------
    df_respostas_rff = pd.read_csv(
        "resultados_incremental_sabia3_1.csv"
    )

    # Converte para string
    df_respostas_rff["resposta"] = df_respostas_rff["resposta"].fillna("").astype(str)


    # Verificação de segurança
    if len(df_respostas_rff) != len(respostas_referencia):
        print(f"⚠️ Aviso: número de respostas não bate! {len(df_respostas_rff)} vs {len(respostas_referencia)}")
    
    # Ajustar tamanho mínimo comum
    n = min(len(df_respostas_rff), len(respostas_referencia))

    respostas_geradas = df_respostas_rff["resposta"].iloc[:n].tolist()
    referencias = respostas_referencia[:n]


    # --------------------------------------------------------------
    # 3) Calcula BERTScore
    # --------------------------------------------------------------
    print("Calculando BERTScore...")
    P, R, F1 = score(respostas_geradas, referencias, lang="pt", verbose=True)


    # --------------------------------------------------------------
    # 4) Monta DataFrame com resultados
    # --------------------------------------------------------------
    df_resultados = pd.DataFrame({
        "resposta_gerada": respostas_geradas,
        "resposta_referencia": referencias,
        "precision": P.tolist(),
        "recall": R.tolist(),
        "f1": F1.tolist()
    })


    # --------------------------------------------------------------
    # 5) Salva em CSV
    # --------------------------------------------------------------
    df_resultados.to_csv('resultados_bertscore_incremental_sabia3_1.csv', index=False)

    print("✅ Arquivo 'resultados_bertscore_incremental_sabia3_1.csv' salvo com sucesso.")
    print(f"\n✅ Média F1: {F1.mean().item():.4f}")
# Out:
# Calculando BERTScore...
# calculating scores...
# computing bert embedding.
#   0%|          | 0/6 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/3 [00:00<?, ?it/s]
# done in 140.37 seconds, 1.37 sentences/sec
# ✅ Arquivo 'resultados_bertscore_incremental_sabia3_1.csv' salvo com sucesso.
#
# ✅ Média F1: 0.7814
